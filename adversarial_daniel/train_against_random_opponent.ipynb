# %%
import os
import json
import math
import numpy as np
import tensorflow as tf
import torch

import grid2op
from grid2op.Reward import *
from grid2op.Action import *
from grid2op.Runner import Runner
from grid2op.Reward import L2RPNSandBoxScore, L2RPNReward
from grid2op.Agent import DoNothingAgent

# %run d3qn.ipynb
# %run opponent.ipynb

# %%
def train_d3qn_against_random_opponent(env, agent, opponent, num_pre_training_steps, n_iter,
                                       save_path, log_path):
    # Make sure we can fill the experience buffer
    if num_pre_training_steps < agent.batch_size * agent.num_frames:
        num_pre_training_steps = agent.batch_size * agent.num_frames
        
    # Loop vars
    num_training_steps = n_iter
    num_steps = num_pre_training_steps + num_training_steps
    step = 0
    alive_steps = 0
    total_reward, total_reward_opp = 0, 0
    agent.done = True
    print(f"Total number of steps: {num_steps}")

    # Create file system related vars
    logpath = os.path.join(log_path, agent.name)
    os.makedirs(save_path, exist_ok=True)
    modelpath = os.path.join(save_path, agent.name + ".h5")
    agent.tf_writer = tf.summary.create_file_writer(logpath, name=agent.name)
    agent._save_hyperparameters(save_path, env, num_steps)
    
    while step < num_steps:
        # Init first time or new episode
        if agent.done:
            new_obs = env.reset() # This shouldn't raise
            agent.reset(new_obs)
            opponent.reset()
        if cfg.VERBOSE and step % 1000 == 0:
            print("Step [{}] -- Random [{}]".format(step, agent.epsilon))

        # Save current observation to stacking buffer
        agent._save_current_frame(agent.state)

        # Choose an action
        if step <= num_pre_training_steps:
            a = agent.Qmain.random_move()
        elif np.random.rand(1) < agent.epsilon:
            a = agent.Qmain.random_move()
        elif len(agent.frames) < agent.num_frames:
            a = 0 # Do nothing
        else:
            a, _ = agent.Qmain.predict_move(np.array(agent.frames))

        # Convert it to a valid action
        act = agent.convert_act(a)
        # Execute action
        new_obs, reward, agent.done, info = env.step(act)
        new_state = agent.convert_obs(new_obs)
        if info["is_illegal"] or info["is_ambiguous"] or \
           info["is_dispatching_illegal"] or info["is_illegal_reco"]:
            if cfg.VERBOSE:
                print (a, info)
        total_reward += reward

        # Save new observation to stacking buffer
        agent._save_next_frame(new_state)

        # Save to experience buffer
        if len(agent.frames2) == agent.num_frames:
            agent.per_buffer.add(np.array(agent.frames),
                                a, reward,
                                np.array(agent.frames2),
                                agent.done)

        # Perform training when we have enough experience in buffer
        if step >= num_pre_training_steps:
            training_step = step - num_pre_training_steps
            # Decay chance of random action
            agent.epsilon = agent._adaptive_epsilon_decay(training_step)

            # Perform training at given frequency
            if step % cfg.UPDATE_FREQ == 0 and \
               len(agent.per_buffer) >= agent.batch_size:
                # Perform training
                agent._batch_train(training_step, step)

                if cfg.UPDATE_TARGET_SOFT_TAU > 0.0:
                    tau = cfg.UPDATE_TARGET_SOFT_TAU
                    # Update target network towards primary network
                    agent.Qmain.update_target_soft(agent.Qtarget.model, tau)

            # Every UPDATE_TARGET_HARD_FREQ trainings, update target completely
            if cfg.UPDATE_TARGET_HARD_FREQ > 0 and \
               step % (cfg.UPDATE_FREQ * cfg.UPDATE_TARGET_HARD_FREQ) == 0:
                agent.Qmain.update_target_hard(agent.Qtarget.model)
        
        ######## Opponent #########
        if not agent.done:
            attack = opponent.attack(new_obs)
            if attack is not None:
                print('ATTACK step {}: disconnected {}'.format(step, attack.as_dict()['set_line_status']['disconnected_id'][0]))
                attack_obs, reward_opp, agent.done, info = env.step(attack)
                if info["is_illegal"] or info["is_ambiguous"] or \
                   info["is_dispatching_illegal"] or info["is_illegal_reco"]:
                    if cfg.VERBOSE:
                        print(attack, info)
                total_reward_opp += reward_opp
                new_obs = attack_obs
                opponent.tell_attack_continues(None, None, None, None)
        
        if agent.done:
            agent.epoch_rewards.append(total_reward)
            agent.epoch_alive.append(alive_steps)
            if cfg.VERBOSE and step > num_pre_training_steps:
                print("step {}: Survived [{}] steps".format(step, alive_steps))
                print("Total reward [{}]".format(total_reward))
                print("Total reward opponent [{}]".format(total_reward_opp))
            alive_steps = 0
            total_reward = 0
            total_reward_opp = 0            
        else:
            alive_steps += 1
            
        ######## After Each Step #######
        if step > 0 and step % 2000 == 0: # save network every 5000 iters
            agent.save(modelpath)
        step += 1
        # Make new obs the current obs
        agent.obs = new_obs
        agent.state = new_state

    # Save model after all steps
    agent.save(modelpath)

# %%
# agent params
num_pre_training_steps = 256
learning_rate = 1e-4
initial_epsilon = 0.99
final_epsilon = 0.01
decay_epsilon = 20000
# opponent params
attack_period = 20 # 12 * 24
attack_lines = ['0_1_0', '0_4_1', '11_12_13', '12_13_14', '1_2_2', '1_3_3', '1_4_4', '2_3_5', '3_4_6', '3_6_15', '3_8_16', '4_5_17', '5_10_7', '5_11_8', '5_12_9', '6_7_18', '6_8_19', '8_13_11', '8_9_10', '9_10_12']

# training params
n_iter = 20000
env_name = "rte_case14_realistic"
# env = make(env_name, reward_class=IllegalBadReward)
env = make(env_name, reward_class=CombinedScaledReward)

# Register custom reward for training
cr = env._reward_helper.template_reward
#cr.addReward("overflow", CloseToOverflowReward(), 1.0)
cr.addReward("game", GameplayReward(), 1.0)
#cr.addReward("recolines", LinesReconnectedReward(), 1.0)
cr.addReward("l2rpn", L2RPNReward(), 2.0/float(env.n_line))
# Initialize custom rewards
cr.initialize(env)
# Set reward range to something managable
cr.set_range(-1.0, 1.0)

agent_name = "DDDQN"
save_path = "saved_agent_DDDQN_random_opponent_{}_{}".format(attack_period, n_iter)
log_path="tf_logs_DDDQN"

opponent_name = "Random"

agent = DoubleDuelingDQN(env.observation_space, env.action_space, name=agent_name,
                         is_training=True, learning_rate=learning_rate,
                         initial_epsilon=initial_epsilon, final_epsilon=final_epsilon, decay_epsilon=decay_epsilon)
opponent = RandomOpponent(env.observation_space, env.action_space, lines_attacked=attack_lines,
                          name=opponent_name, attack_period=attack_period)

train_d3qn_against_random_opponent(env, agent, opponent, num_pre_training_steps, n_iter,
                                   save_path, log_path)
# Out:
# Agent action size: 141
# Total number of steps: 20256
# Step [0] -- Random [0.99]
# ATTACK step 1: disconnected 6
# ATTACK step 91: disconnected 18
# ATTACK step 196: disconnected 17
# ATTACK step 225: disconnected 15
# ATTACK step 240: disconnected 2
# ATTACK step 245: disconnected 1
# 11 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#         True, False,  True, False, False,  True, False,  True,  True,
#        False, False]), 'is_illegal': True, 'is_ambiguous': False, 'is_dispatching_illegal': False, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException IllegalAction IllegalAction('Powerline with ids [10] have been modified illegally (cooldown)',), Grid2OpException DivergingPowerFlow DivergingPowerFlow('GAME OVER: Powerflow has diverged during computation or a load has been disconnected or a generator has been disconnected.',)], 'rewards': {}}
# ATTACK step 257: disconnected 12
# step 257: Survived [1] steps
# Total reward [1.4382268190383911]
# Total reward opponent [-1.0]
# step 259: Survived [1] steps
# Total reward [-0.22041559219360352]
# Total reward opponent [0]
# step 261: Survived [1] steps
# Total reward [-0.25496792793273926]
# Total reward opponent [0]
# step 264: Survived [2] steps
# Total reward [0.5219745635986328]
# Total reward opponent [0]
# step 266: Survived [1] steps
# Total reward [-0.2500976324081421]
# Total reward opponent [0]
# step 269: Survived [2] steps
# Total reward [0.30026137828826904]
# Total reward opponent [0]
# step 273: Survived [3] steps
# Total reward [1.3463032245635986]
# Total reward opponent [0]
# step 278: Survived [4] steps
# Total reward [2.074373960494995]
# Total reward opponent [0]
# loss = 1480.9436
# step 282: Survived [3] steps
# Total reward [1.2878683805465698]
# Total reward opponent [0]
# step 286: Survived [3] steps
# Total reward [1.167709469795227]
# Total reward opponent [0]
# step 289: Survived [2] steps
# Total reward [0.5402822494506836]
# Total reward opponent [0]
# step 293: Survived [3] steps
# Total reward [1.1973719596862793]
# Total reward opponent [0]
# step 294: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 296: Survived [1] steps
# Total reward [-0.24296152591705322]
# Total reward opponent [0]
# ATTACK step 297: disconnected 5
# step 301: Survived [4] steps
# Total reward [2.102887272834778]
# Total reward opponent [0.7785422801971436]
# step 305: Survived [3] steps
# Total reward [1.3425087928771973]
# Total reward opponent [0]
# step 306: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 308: Survived [1] steps
# Total reward [-0.17038202285766602]
# Total reward opponent [0]
# step 310: Survived [1] steps
# Total reward [-0.21047818660736084]
# Total reward opponent [0]
# step 314: Survived [3] steps
# Total reward [1.3636661767959595]
# Total reward opponent [0]
# step 315: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 320: Survived [4] steps
# Total reward [2.139593005180359]
# Total reward opponent [0]
# step 321: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 323: Survived [1] steps
# Total reward [-0.23617279529571533]
# Total reward opponent [0]
# step 325: Survived [1] steps
# Total reward [-0.22294235229492188]
# Total reward opponent [0]
# step 326: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 327: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 330: Survived [2] steps
# Total reward [0.561215877532959]
# Total reward opponent [0]
# step 331: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 334: Survived [2] steps
# Total reward [0.47680211067199707]
# Total reward opponent [0]
# loss = 66.37141
# step 336: Survived [1] steps
# Total reward [-0.21596407890319824]
# Total reward opponent [0]
# step 338: Survived [1] steps
# Total reward [-0.25161075592041016]
# Total reward opponent [0]
# step 340: Survived [1] steps
# Total reward [-0.20577764511108398]
# Total reward opponent [0]
# step 345: Survived [4] steps
# Total reward [2.1314845085144043]
# Total reward opponent [0]
# step 346: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 349: Survived [2] steps
# Total reward [0.46137678623199463]
# Total reward opponent [0]
# step 351: Survived [1] steps
# Total reward [-0.20209455490112305]
# Total reward opponent [0]
# step 352: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 354: Survived [1] steps
# Total reward [-0.22888803482055664]
# Total reward opponent [0]
# step 355: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 357: Survived [1] steps
# Total reward [-0.2119007110595703]
# Total reward opponent [0]
# step 360: Survived [2] steps
# Total reward [0.2198237180709839]
# Total reward opponent [0]
# step 362: Survived [1] steps
# Total reward [-0.254425048828125]
# Total reward opponent [0]
# step 365: Survived [2] steps
# Total reward [0.42487025260925293]
# Total reward opponent [0]
# step 366: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 370: Survived [3] steps
# Total reward [1.4296939373016357]
# Total reward opponent [0]
# step 373: Survived [2] steps
# Total reward [0.6386927366256714]
# Total reward opponent [0]
# step 378: Survived [4] steps
# Total reward [2.2418484687805176]
# Total reward opponent [0]
# step 384: Survived [5] steps
# Total reward [2.790342092514038]
# Total reward opponent [0]
# step 386: Survived [1] steps
# Total reward [-0.26350367069244385]
# Total reward opponent [0]
# step 388: Survived [1] steps
# Total reward [-0.2047879695892334]
# Total reward opponent [0]
# step 391: Survived [2] steps
# Total reward [0.449202299118042]
# Total reward opponent [0]
# loss = 88.18848
# step 393: Survived [1] steps
# Total reward [-0.1999596357345581]
# Total reward opponent [0]
# step 396: Survived [2] steps
# Total reward [0.5117968320846558]
# Total reward opponent [0]
# step 401: Survived [4] steps
# Total reward [2.0916595458984375]
# Total reward opponent [0]
# step 403: Survived [1] steps
# Total reward [-0.23317384719848633]
# Total reward opponent [0]
# step 407: Survived [3] steps
# Total reward [1.0482511520385742]
# Total reward opponent [0]
# step 410: Survived [2] steps
# Total reward [0.4725015163421631]
# Total reward opponent [0]
# step 413: Survived [2] steps
# Total reward [0.5591070652008057]
# Total reward opponent [0]
# ATTACK step 419: disconnected 9
# step 420: Survived [6] steps
# Total reward [3.5781725645065308]
# Total reward opponent [0.6987054347991943]
# step 423: Survived [2] steps
# Total reward [0.41690754890441895]
# Total reward opponent [0]
# step 426: Survived [2] steps
# Total reward [0.5471956729888916]
# Total reward opponent [0]
# step 427: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 428: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 431: Survived [2] steps
# Total reward [0.5871939659118652]
# Total reward opponent [0]
# step 433: Survived [1] steps
# Total reward [-0.2986412048339844]
# Total reward opponent [0]
# step 435: Survived [1] steps
# Total reward [-0.2635054588317871]
# Total reward opponent [0]
# step 438: Survived [2] steps
# Total reward [0.4670431613922119]
# Total reward opponent [0]
# step 440: Survived [1] steps
# Total reward [-0.21890711784362793]
# Total reward opponent [0]
# step 441: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 443: Survived [1] steps
# Total reward [-0.25018417835235596]
# Total reward opponent [0]
# step 444: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 21.472313
# step 449: Survived [4] steps
# Total reward [2.0441861152648926]
# Total reward opponent [0]
# step 454: Survived [4] steps
# Total reward [2.2486777305603027]
# Total reward opponent [0]
# step 456: Survived [1] steps
# Total reward [-0.23711085319519043]
# Total reward opponent [0]
# step 460: Survived [3] steps
# Total reward [1.047818660736084]
# Total reward opponent [0]
# step 463: Survived [2] steps
# Total reward [0.5254799127578735]
# Total reward opponent [0]
# step 464: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 466: Survived [1] steps
# Total reward [-0.3799043893814087]
# Total reward opponent [0]
# ATTACK step 467: disconnected 6
# step 469: Survived [2] steps
# Total reward [0.5203551054000854]
# Total reward opponent [0.7583127021789551]
# step 470: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 472: Survived [1] steps
# Total reward [-0.15654075145721436]
# Total reward opponent [0]
# step 476: Survived [3] steps
# Total reward [1.1406135559082031]
# Total reward opponent [0]
# ATTACK step 478: disconnected 18
# step 478: Survived [1] steps
# Total reward [1.465042233467102]
# Total reward opponent [-1.0]
# step 479: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 482: Survived [2] steps
# Total reward [0.5158997774124146]
# Total reward opponent [0]
# step 488: Survived [5] steps
# Total reward [2.8533897399902344]
# Total reward opponent [0]
# step 490: Survived [1] steps
# Total reward [-0.2076730728149414]
# Total reward opponent [0]
# step 492: Survived [1] steps
# Total reward [-0.448319673538208]
# Total reward opponent [0]
# step 493: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 496: Survived [2] steps
# Total reward [0.45682477951049805]
# Total reward opponent [0]
# ATTACK step 498: disconnected 0
# step 501: Survived [4] steps
# Total reward [2.2263232469558716]
# Total reward opponent [0.825023889541626]
# step 502: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 17.367651
# step 508: Survived [5] steps
# Total reward [2.9129456281661987]
# Total reward opponent [0]
# step 511: Survived [2] steps
# Total reward [0.623744010925293]
# Total reward opponent [0]
# step 514: Survived [2] steps
# Total reward [0.5684106349945068]
# Total reward opponent [0]
# step 515: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 516: disconnected 17
# step 517: Survived [1] steps
# Total reward [-0.19458246231079102]
# Total reward opponent [0.837510347366333]
# step 519: Survived [1] steps
# Total reward [-0.18974995613098145]
# Total reward opponent [0]
# step 521: Survived [1] steps
# Total reward [-0.3063685894012451]
# Total reward opponent [0]
# step 527: Survived [5] steps
# Total reward [2.8706125020980835]
# Total reward opponent [0]
# step 531: Survived [3] steps
# Total reward [1.330559253692627]
# Total reward opponent [0]
# step 532: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 533: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 537: Survived [3] steps
# Total reward [1.1975970268249512]
# Total reward opponent [0]
# step 544: Survived [6] steps
# Total reward [3.376723885536194]
# Total reward opponent [0]
# ATTACK step 545: disconnected 16
# step 547: Survived [2] steps
# Total reward [0.5584831237792969]
# Total reward opponent [0.8099863529205322]
# step 548: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 550: Survived [1] steps
# Total reward [-0.2453908920288086]
# Total reward opponent [0]
# step 552: Survived [1] steps
# Total reward [-0.25301027297973633]
# Total reward opponent [0]
# step 553: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 556: Survived [2] steps
# Total reward [0.5668597221374512]
# Total reward opponent [0]
# step 559: Survived [2] steps
# Total reward [0.5400466918945312]
# Total reward opponent [0]
# loss = 11.864231
# step 562: Survived [2] steps
# Total reward [0.6269806623458862]
# Total reward opponent [0]
# step 565: Survived [2] steps
# Total reward [0.3700411319732666]
# Total reward opponent [0]
# step 568: Survived [2] steps
# Total reward [0.5527868270874023]
# Total reward opponent [0]
# step 570: Survived [1] steps
# Total reward [-0.21080827713012695]
# Total reward opponent [0]
# step 572: Survived [1] steps
# Total reward [-0.23952317237854004]
# Total reward opponent [0]
# step 573: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 575: disconnected 19
# step 576: Survived [2] steps
# Total reward [0.5862053632736206]
# Total reward opponent [0.7035819292068481]
# step 579: Survived [2] steps
# Total reward [0.4636038541793823]
# Total reward opponent [0]
# step 585: Survived [5] steps
# Total reward [3.008756160736084]
# Total reward opponent [0]
# step 586: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 587: disconnected 15
# step 588: Survived [1] steps
# Total reward [-0.1999187469482422]
# Total reward opponent [0.7808053493499756]
# step 589: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 590: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 591: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 595: Survived [3] steps
# Total reward [1.2554090023040771]
# Total reward opponent [0]
# ATTACK step 596: disconnected 7
# step 597: Survived [1] steps
# Total reward [-0.1860806941986084]
# Total reward opponent [0.7732430696487427]
# step 599: Survived [1] steps
# Total reward [-0.19500136375427246]
# Total reward opponent [0]
# step 603: Survived [3] steps
# Total reward [1.2205092906951904]
# Total reward opponent [0]
# step 605: Survived [1] steps
# Total reward [-0.2179962396621704]
# Total reward opponent [0]
# step 608: Survived [2] steps
# Total reward [0.4260258674621582]
# Total reward opponent [0]
# step 609: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 610: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 612: Survived [1] steps
# Total reward [-0.20473980903625488]
# Total reward opponent [0]
# step 613: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 13.67314
# step 616: Survived [2] steps
# Total reward [0.47990119457244873]
# Total reward opponent [0]
# step 618: Survived [1] steps
# Total reward [-0.2630208730697632]
# Total reward opponent [0]
# step 624: Survived [5] steps
# Total reward [2.7826870679855347]
# Total reward opponent [0]
# step 625: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 626: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 628: Survived [1] steps
# Total reward [-0.24549627304077148]
# Total reward opponent [0]
# step 629: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 631: disconnected 10
# step 634: Survived [4] steps
# Total reward [1.7558459043502808]
# Total reward opponent [0.8022549152374268]
# step 635: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 639: Survived [3] steps
# Total reward [1.047974705696106]
# Total reward opponent [0]
# step 645: Survived [5] steps
# Total reward [3.0598069429397583]
# Total reward opponent [0]
# step 646: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 649: disconnected 7
# step 650: Survived [3] steps
# Total reward [1.2196106910705566]
# Total reward opponent [0.7047300338745117]
# step 652: Survived [1] steps
# Total reward [-0.18578648567199707]
# Total reward opponent [0]
# step 657: Survived [4] steps
# Total reward [2.009982705116272]
# Total reward opponent [0]
# step 660: Survived [2] steps
# Total reward [0.5969181060791016]
# Total reward opponent [0]
# step 664: Survived [3] steps
# Total reward [1.3598110675811768]
# Total reward opponent [0]
# step 667: Survived [2] steps
# Total reward [0.4842756986618042]
# Total reward opponent [0]
# step 671: Survived [3] steps
# Total reward [1.243111252784729]
# Total reward opponent [0]
# loss = 5.221888
# step 673: Survived [1] steps
# Total reward [-0.23215341567993164]
# Total reward opponent [0]
# step 676: Survived [2] steps
# Total reward [0.5608268976211548]
# Total reward opponent [0]
# step 677: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 678: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 680: Survived [1] steps
# Total reward [-0.2455739974975586]
# Total reward opponent [0]
# step 683: Survived [2] steps
# Total reward [0.46868813037872314]
# Total reward opponent [0]
# step 685: Survived [1] steps
# Total reward [-0.23622655868530273]
# Total reward opponent [0]
# step 689: Survived [3] steps
# Total reward [1.1564457416534424]
# Total reward opponent [0]
# step 692: Survived [2] steps
# Total reward [0.6018979549407959]
# Total reward opponent [0]
# step 696: Survived [3] steps
# Total reward [1.1989357471466064]
# Total reward opponent [0]
# step 698: Survived [1] steps
# Total reward [-0.22399723529815674]
# Total reward opponent [0]
# step 700: Survived [1] steps
# Total reward [-0.20800244808197021]
# Total reward opponent [0]
# ATTACK step 702: disconnected 4
# step 702: Survived [1] steps
# Total reward [1.4106090068817139]
# Total reward opponent [-1.0]
# step 706: Survived [3] steps
# Total reward [1.4324209690093994]
# Total reward opponent [0]
# step 709: Survived [2] steps
# Total reward [0.16784453392028809]
# Total reward opponent [0]
# step 710: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 711: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 715: Survived [3] steps
# Total reward [1.3093748092651367]
# Total reward opponent [0]
# step 716: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 717: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 719: Survived [1] steps
# Total reward [-0.26376330852508545]
# Total reward opponent [0]
# step 721: Survived [1] steps
# Total reward [-0.20497393608093262]
# Total reward opponent [0]
# step 724: Survived [2] steps
# Total reward [0.5100200176239014]
# Total reward opponent [0]
# step 727: Survived [2] steps
# Total reward [0.44681787490844727]
# Total reward opponent [0]
# loss = 19.07829
# step 730: Survived [2] steps
# Total reward [0.45963096618652344]
# Total reward opponent [0]
# step 734: Survived [3] steps
# Total reward [1.0749626159667969]
# Total reward opponent [0]
# step 737: Survived [2] steps
# Total reward [0.33296382427215576]
# Total reward opponent [0]
# ATTACK step 738: disconnected 6
# step 739: Survived [1] steps
# Total reward [-0.32579469680786133]
# Total reward opponent [0.671151876449585]
# ATTACK step 740: disconnected 17
# step 741: Survived [1] steps
# Total reward [-0.1927204132080078]
# Total reward opponent [0.7483549118041992]
# step 744: Survived [2] steps
# Total reward [0.4549686908721924]
# Total reward opponent [0]
# step 749: Survived [4] steps
# Total reward [1.8827153444290161]
# Total reward opponent [0]
# step 753: Survived [3] steps
# Total reward [1.140575647354126]
# Total reward opponent [0]
# step 755: Survived [1] steps
# Total reward [-0.22484540939331055]
# Total reward opponent [0]
# step 758: Survived [2] steps
# Total reward [0.5437308549880981]
# Total reward opponent [0]
# step 764: Survived [5] steps
# Total reward [2.9354617595672607]
# Total reward opponent [0]
# step 767: Survived [2] steps
# Total reward [0.5496011972427368]
# Total reward opponent [0]
# step 769: Survived [1] steps
# Total reward [-0.17714345455169678]
# Total reward opponent [0]
# step 772: Survived [2] steps
# Total reward [0.43971121311187744]
# Total reward opponent [0]
# step 775: Survived [2] steps
# Total reward [0.547675371170044]
# Total reward opponent [0]
# step 776: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 779: disconnected 17
# step 779: Survived [2] steps
# Total reward [2.3710638284683228]
# Total reward opponent [-1.0]
# step 780: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 5.162235
# step 787: Survived [6] steps
# Total reward [3.579072952270508]
# Total reward opponent [0]
# step 788: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 792: Survived [3] steps
# Total reward [1.416495442390442]
# Total reward opponent [0]
# ATTACK step 796: disconnected 17
# step 797: Survived [4] steps
# Total reward [2.218651294708252]
# Total reward opponent [0.775836706161499]
# step 801: Survived [3] steps
# Total reward [1.3160984516143799]
# Total reward opponent [0]
# step 804: Survived [2] steps
# Total reward [0.5247800350189209]
# Total reward opponent [0]
# step 807: Survived [2] steps
# Total reward [0.4019123315811157]
# Total reward opponent [0]
# step 810: Survived [2] steps
# Total reward [0.6161471605300903]
# Total reward opponent [0]
# step 811: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 816: Survived [4] steps
# Total reward [1.878256916999817]
# Total reward opponent [0]
# step 820: Survived [3] steps
# Total reward [1.1436997652053833]
# Total reward opponent [0]
# step 821: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 825: Survived [3] steps
# Total reward [1.3394429683685303]
# Total reward opponent [0]
# step 826: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 827: disconnected 8
# step 829: Survived [2] steps
# Total reward [0.40074622631073]
# Total reward opponent [0.7087292671203613]
# step 832: Survived [2] steps
# Total reward [0.5038156509399414]
# Total reward opponent [0]
# step 834: Survived [1] steps
# Total reward [-0.2710038423538208]
# Total reward opponent [0]
# step 837: Survived [2] steps
# Total reward [0.49605846405029297]
# Total reward opponent [0]
# ATTACK step 839: disconnected 7
# loss = 6.551306
# step 841: Survived [3] steps
# Total reward [1.2700090408325195]
# Total reward opponent [0.737933874130249]
# step 844: Survived [2] steps
# Total reward [0.2539989948272705]
# Total reward opponent [0]
# step 847: Survived [2] steps
# Total reward [0.5620212554931641]
# Total reward opponent [0]
# step 851: Survived [3] steps
# Total reward [1.3994847536087036]
# Total reward opponent [0]
# step 856: Survived [4] steps
# Total reward [1.9669731855392456]
# Total reward opponent [0]
# step 861: Survived [4] steps
# Total reward [2.1188780069351196]
# Total reward opponent [0]
# ATTACK step 862: disconnected 17
# step 866: Survived [4] steps
# Total reward [2.149716019630432]
# Total reward opponent [0.768722414970398]
# step 867: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 871: Survived [3] steps
# Total reward [1.3703806400299072]
# Total reward opponent [0]
# step 874: Survived [2] steps
# Total reward [0.4968661069869995]
# Total reward opponent [0]
# step 878: Survived [3] steps
# Total reward [1.3109211921691895]
# Total reward opponent [0]
# step 880: Survived [1] steps
# Total reward [-0.3232874870300293]
# Total reward opponent [0]
# step 882: Survived [1] steps
# Total reward [-0.22008681297302246]
# Total reward opponent [0]
# step 883: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 886: Survived [2] steps
# Total reward [0.5836067199707031]
# Total reward opponent [0]
# step 888: Survived [1] steps
# Total reward [-0.25217747688293457]
# Total reward opponent [0]
# step 895: Survived [6] steps
# Total reward [3.4725335836410522]
# Total reward opponent [0]
# loss = 10.919879
# step 898: Survived [2] steps
# Total reward [0.571406364440918]
# Total reward opponent [0]
# step 902: Survived [3] steps
# Total reward [1.1517049074172974]
# Total reward opponent [0]
# step 906: Survived [3] steps
# Total reward [1.218389630317688]
# Total reward opponent [0]
# step 910: Survived [3] steps
# Total reward [1.2417011260986328]
# Total reward opponent [0]
# step 911: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 916: Survived [4] steps
# Total reward [2.0956188440322876]
# Total reward opponent [0]
# step 917: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 920: disconnected 0
# step 923: Survived [5] steps
# Total reward [2.7730947732925415]
# Total reward opponent [0.7647315263748169]
# step 926: Survived [2] steps
# Total reward [0.4652324914932251]
# Total reward opponent [0]
# step 932: Survived [5] steps
# Total reward [2.816788911819458]
# Total reward opponent [0]
# step 933: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 935: Survived [1] steps
# Total reward [-0.1695401668548584]
# Total reward opponent [0]
# step 937: Survived [1] steps
# Total reward [-0.2237379550933838]
# Total reward opponent [0]
# step 940: Survived [2] steps
# Total reward [0.43088316917419434]
# Total reward opponent [0]
# step 943: Survived [2] steps
# Total reward [0.5111372470855713]
# Total reward opponent [0]
# step 948: Survived [4] steps
# Total reward [2.025333046913147]
# Total reward opponent [0]
# step 950: Survived [1] steps
# Total reward [-0.324163556098938]
# Total reward opponent [0]
# loss = 20.527504
# step 953: Survived [2] steps
# Total reward [0.5503532886505127]
# Total reward opponent [0]
# step 958: Survived [4] steps
# Total reward [2.2512636184692383]
# Total reward opponent [0]
# ATTACK step 959: disconnected 8
# step 961: Survived [2] steps
# Total reward [0.5002285242080688]
# Total reward opponent [0.7450149059295654]
# step 964: Survived [2] steps
# Total reward [0.24255812168121338]
# Total reward opponent [0]
# step 969: Survived [4] steps
# Total reward [1.997821569442749]
# Total reward opponent [0]
# step 972: Survived [2] steps
# Total reward [0.5064742565155029]
# Total reward opponent [0]
# step 974: Survived [1] steps
# Total reward [-0.21124482154846191]
# Total reward opponent [0]
# step 980: Survived [5] steps
# Total reward [2.71866512298584]
# Total reward opponent [0]
# step 982: Survived [1] steps
# Total reward [-0.22124743461608887]
# Total reward opponent [0]
# step 985: Survived [2] steps
# Total reward [0.5439724922180176]
# Total reward opponent [0]
# step 986: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 987: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 993: Survived [5] steps
# Total reward [2.4450786113739014]
# Total reward opponent [0]
# step 995: Survived [1] steps
# Total reward [-0.2667757272720337]
# Total reward opponent [0]
# step 999: Survived [3] steps
# Total reward [1.3453102111816406]
# Total reward opponent [0]
# Step [1000] -- Random [0.8949981880496173]
# step 1001: Survived [1] steps
# Total reward [-0.19566822052001953]
# Total reward opponent [0]
# ATTACK step 1002: disconnected 18
# step 1002: Survived [0] steps
# Total reward [0.6514813899993896]
# Total reward opponent [-1.0]
# step 1005: Survived [2] steps
# Total reward [0.30945849418640137]
# Total reward opponent [0]
# step 1006: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 8.97258
# step 1011: Survived [4] steps
# Total reward [2.0078083276748657]
# Total reward opponent [0]
# step 1013: Survived [1] steps
# Total reward [-0.19314801692962646]
# Total reward opponent [0]
# step 1018: Survived [4] steps
# Total reward [2.001974940299988]
# Total reward opponent [0]
# step 1022: Survived [3] steps
# Total reward [1.416487693786621]
# Total reward opponent [0]
# step 1024: Survived [1] steps
# Total reward [-0.1920642852783203]
# Total reward opponent [0]
# step 1027: Survived [2] steps
# Total reward [0.47842490673065186]
# Total reward opponent [0]
# ATTACK step 1033: disconnected 9
# step 1033: Survived [5] steps
# Total reward [4.702244400978088]
# Total reward opponent [-1.0]
# step 1037: Survived [3] steps
# Total reward [1.421312689781189]
# Total reward opponent [0]
# ATTACK step 1038: disconnected 3
# step 1040: Survived [2] steps
# Total reward [0.3185083866119385]
# Total reward opponent [0.6058766841888428]
# step 1043: Survived [2] steps
# Total reward [0.3777616024017334]
# Total reward opponent [0]
# step 1046: Survived [2] steps
# Total reward [0.5904350280761719]
# Total reward opponent [0]
# step 1048: Survived [1] steps
# Total reward [-0.1987156867980957]
# Total reward opponent [0]
# step 1050: Survived [1] steps
# Total reward [-0.21941304206848145]
# Total reward opponent [0]
# step 1051: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1053: Survived [1] steps
# Total reward [-0.23308074474334717]
# Total reward opponent [0]
# step 1057: Survived [3] steps
# Total reward [1.3973463773727417]
# Total reward opponent [0]
# step 1060: Survived [2] steps
# Total reward [0.4527018070220947]
# Total reward opponent [0]
# step 1063: Survived [2] steps
# Total reward [0.605880618095398]
# Total reward opponent [0]
# loss = 10.780001
# step 1066: Survived [2] steps
# Total reward [0.37794601917266846]
# Total reward opponent [0]
# ATTACK step 1067: disconnected 17
# step 1067: Survived [0] steps
# Total reward [0.7402217388153076]
# Total reward opponent [-1.0]
# step 1069: Survived [1] steps
# Total reward [-0.1695418357849121]
# Total reward opponent [0]
# step 1072: Survived [2] steps
# Total reward [0.4791278839111328]
# Total reward opponent [0]
# step 1076: Survived [3] steps
# Total reward [1.4299277067184448]
# Total reward opponent [0]
# step 1077: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1081: Survived [3] steps
# Total reward [1.4683358669281006]
# Total reward opponent [0]
# ATTACK step 1084: disconnected 18
# step 1084: Survived [2] steps
# Total reward [2.3655964136123657]
# Total reward opponent [-1.0]
# step 1085: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1088: Survived [2] steps
# Total reward [0.5201632976531982]
# Total reward opponent [0]
# step 1091: Survived [2] steps
# Total reward [0.4078875780105591]
# Total reward opponent [0]
# ATTACK step 1098: disconnected 18
# step 1098: Survived [6] steps
# Total reward [5.211485147476196]
# Total reward opponent [-1.0]
# step 1099: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1101: Survived [1] steps
# Total reward [-0.20180439949035645]
# Total reward opponent [0]
# step 1102: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1105: Survived [2] steps
# Total reward [0.583743691444397]
# Total reward opponent [0]
# step 1108: Survived [2] steps
# Total reward [0.5598777532577515]
# Total reward opponent [0]
# step 1113: Survived [4] steps
# Total reward [2.1286741495132446]
# Total reward opponent [0]
# step 1114: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1117: Survived [2] steps
# Total reward [0.40281593799591064]
# Total reward opponent [0]
# loss = 8.160959
# step 1121: Survived [3] steps
# Total reward [1.349092721939087]
# Total reward opponent [0]
# step 1123: Survived [1] steps
# Total reward [-0.25518155097961426]
# Total reward opponent [0]
# step 1124: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1125: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 1127: disconnected 2
# step 1131: Survived [5] steps
# Total reward [2.8011103868484497]
# Total reward opponent [0.7472326755523682]
# ATTACK step 1133: disconnected 17
# step 1133: Survived [1] steps
# Total reward [1.4487035274505615]
# Total reward opponent [-1.0]
# step 1137: Survived [3] steps
# Total reward [1.1336228847503662]
# Total reward opponent [0]
# step 1139: Survived [1] steps
# Total reward [-0.2566807270050049]
# Total reward opponent [0]
# step 1143: Survived [3] steps
# Total reward [1.2263933420181274]
# Total reward opponent [0]
# step 1147: Survived [3] steps
# Total reward [1.2160667181015015]
# Total reward opponent [0]
# step 1148: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1151: Survived [2] steps
# Total reward [0.511328935623169]
# Total reward opponent [0]
# step 1156: Survived [4] steps
# Total reward [2.218024253845215]
# Total reward opponent [0]
# step 1160: Survived [3] steps
# Total reward [1.1949055194854736]
# Total reward opponent [0]
# step 1161: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1163: Survived [1] steps
# Total reward [-0.26446640491485596]
# Total reward opponent [0]
# ATTACK step 1166: disconnected 18
# step 1166: Survived [2] steps
# Total reward [2.4376680850982666]
# Total reward opponent [-1.0]
# step 1168: Survived [1] steps
# Total reward [-0.22007369995117188]
# Total reward opponent [0]
# step 1171: Survived [2] steps
# Total reward [0.5458506345748901]
# Total reward opponent [0]
# loss = 8.28656
# step 1176: Survived [4] steps
# Total reward [1.9859055280685425]
# Total reward opponent [0]
# step 1177: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1180: Survived [2] steps
# Total reward [0.4771538972854614]
# Total reward opponent [0]
# step 1182: Survived [1] steps
# Total reward [-0.23146367073059082]
# Total reward opponent [0]
# step 1183: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1184: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1185: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1188: Survived [2] steps
# Total reward [0.5046718120574951]
# Total reward opponent [0]
# step 1192: Survived [3] steps
# Total reward [1.4530240297317505]
# Total reward opponent [0]
# ATTACK step 1193: disconnected 2
# step 1195: Survived [2] steps
# Total reward [0.37872016429901123]
# Total reward opponent [0.6580415964126587]
# step 1197: Survived [1] steps
# Total reward [-0.17485427856445312]
# Total reward opponent [0]
# step 1200: Survived [2] steps
# Total reward [0.41320037841796875]
# Total reward opponent [0]
# step 1207: Survived [6] steps
# Total reward [3.5497095584869385]
# Total reward opponent [0]
# ATTACK step 1208: disconnected 0
# step 1211: Survived [3] steps
# Total reward [1.319722056388855]
# Total reward opponent [0.792189359664917]
# step 1217: Survived [5] steps
# Total reward [2.981803059577942]
# Total reward opponent [0]
# step 1220: Survived [2] steps
# Total reward [0.6432523727416992]
# Total reward opponent [0]
# step 1223: Survived [2] steps
# Total reward [0.5423247814178467]
# Total reward opponent [0]
# step 1226: Survived [2] steps
# Total reward [0.5625455379486084]
# Total reward opponent [0]
# step 1228: Survived [1] steps
# Total reward [-0.19688081741333008]
# Total reward opponent [0]
# loss = 10.950539
# step 1233: Survived [4] steps
# Total reward [1.9085216522216797]
# Total reward opponent [0]
# ATTACK step 1234: disconnected 5
# step 1237: Survived [3] steps
# Total reward [1.3197029829025269]
# Total reward opponent [0.7703895568847656]
# ATTACK step 1239: disconnected 12
# step 1240: Survived [2] steps
# Total reward [0.5035170316696167]
# Total reward opponent [0.7109348773956299]
# step 1243: Survived [2] steps
# Total reward [0.6276243925094604]
# Total reward opponent [0]
# step 1244: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1247: Survived [2] steps
# Total reward [0.4707258939743042]
# Total reward opponent [0]
# step 1252: Survived [4] steps
# Total reward [2.0941836833953857]
# Total reward opponent [0]
# step 1255: Survived [2] steps
# Total reward [0.4603993892669678]
# Total reward opponent [0]
# step 1258: Survived [2] steps
# Total reward [0.49730896949768066]
# Total reward opponent [0]
# step 1261: Survived [2] steps
# Total reward [0.46933674812316895]
# Total reward opponent [0]
# step 1264: Survived [2] steps
# Total reward [0.3688802719116211]
# Total reward opponent [0]
# step 1266: Survived [1] steps
# Total reward [-0.41733527183532715]
# Total reward opponent [0]
# step 1267: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1269: Survived [1] steps
# Total reward [-0.21068143844604492]
# Total reward opponent [0]
# step 1276: Survived [6] steps
# Total reward [3.5090384483337402]
# Total reward opponent [0]
# step 1280: Survived [3] steps
# Total reward [1.2849299907684326]
# Total reward opponent [0]
# step 1281: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 6.230938
# step 1288: Survived [6] steps
# Total reward [3.4693119525909424]
# Total reward opponent [0]
# step 1293: Survived [4] steps
# Total reward [2.016378164291382]
# Total reward opponent [0]
# step 1296: Survived [2] steps
# Total reward [0.5396683216094971]
# Total reward opponent [0]
# step 1299: Survived [2] steps
# Total reward [0.40093016624450684]
# Total reward opponent [0]
# step 1302: Survived [2] steps
# Total reward [0.5503983497619629]
# Total reward opponent [0]
# step 1303: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1309: Survived [5] steps
# Total reward [2.815324544906616]
# Total reward opponent [0]
# step 1310: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1314: Survived [3] steps
# Total reward [1.4532512426376343]
# Total reward opponent [0]
# step 1318: Survived [3] steps
# Total reward [1.286096215248108]
# Total reward opponent [0]
# step 1324: Survived [5] steps
# Total reward [2.7213375568389893]
# Total reward opponent [0]
# ATTACK step 1326: disconnected 4
# step 1329: Survived [4] steps
# Total reward [1.9102905988693237]
# Total reward opponent [0.7813777923583984]
# step 1330: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1335: Survived [4] steps
# Total reward [2.0668972730636597]
# Total reward opponent [0]
# step 1339: Survived [3] steps
# Total reward [1.1276956796646118]
# Total reward opponent [0]
# step 1341: Survived [1] steps
# Total reward [-0.28489065170288086]
# Total reward opponent [0]
# step 1342: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 7.6834683
# step 1347: Survived [4] steps
# Total reward [1.8586747646331787]
# Total reward opponent [0]
# step 1351: Survived [3] steps
# Total reward [1.3548121452331543]
# Total reward opponent [0]
# step 1355: Survived [3] steps
# Total reward [1.2479989528656006]
# Total reward opponent [0]
# step 1358: Survived [2] steps
# Total reward [0.5492370128631592]
# Total reward opponent [0]
# step 1359: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1362: Survived [2] steps
# Total reward [0.379713773727417]
# Total reward opponent [0]
# step 1366: Survived [3] steps
# Total reward [1.3940826654434204]
# Total reward opponent [0]
# step 1367: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1372: Survived [4] steps
# Total reward [1.9783812761306763]
# Total reward opponent [0]
# step 1375: Survived [2] steps
# Total reward [0.337954044342041]
# Total reward opponent [0]
# ATTACK step 1377: disconnected 4
# step 1380: Survived [4] steps
# Total reward [2.314340591430664]
# Total reward opponent [0.8302969932556152]
# ATTACK step 1382: disconnected 4
# step 1383: Survived [2] steps
# Total reward [0.4671405553817749]
# Total reward opponent [0.6959617137908936]
# step 1387: Survived [3] steps
# Total reward [1.3092762231826782]
# Total reward opponent [0]
# step 1390: Survived [2] steps
# Total reward [0.4898414611816406]
# Total reward opponent [0]
# step 1393: Survived [2] steps
# Total reward [0.558158278465271]
# Total reward opponent [0]
# step 1396: Survived [2] steps
# Total reward [0.536393404006958]
# Total reward opponent [0]
# loss = 8.3870945
# ATTACK step 1403: disconnected 7
# step 1403: Survived [6] steps
# Total reward [5.551726460456848]
# Total reward opponent [-1.0]
# step 1405: Survived [1] steps
# Total reward [-0.4965941905975342]
# Total reward opponent [0]
# step 1409: Survived [3] steps
# Total reward [1.4651128053665161]
# Total reward opponent [0]
# step 1411: Survived [1] steps
# Total reward [-0.20924973487854004]
# Total reward opponent [0]
# step 1412: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1413: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1414: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1416: Survived [1] steps
# Total reward [-0.2198648452758789]
# Total reward opponent [0]
# step 1417: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1418: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 1421: disconnected 4
# ATTACK step 1422: disconnected 3
# step 1423: Survived [4] steps
# Total reward [2.0855534076690674]
# Total reward opponent [1.370842695236206]
# step 1426: Survived [2] steps
# Total reward [0.4656805992126465]
# Total reward opponent [0]
# step 1427: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 1428: disconnected 18
# step 1428: Survived [0] steps
# Total reward [0.744943380355835]
# Total reward opponent [-1.0]
# step 1430: Survived [1] steps
# Total reward [-0.19085216522216797]
# Total reward opponent [0]
# step 1440: Survived [9] steps
# Total reward [6.16344153881073]
# Total reward opponent [0]
# step 1441: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1444: Survived [2] steps
# Total reward [0.6254072189331055]
# Total reward opponent [0]
# step 1449: Survived [4] steps
# Total reward [2.1058658361434937]
# Total reward opponent [0]
# step 1450: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1454: Survived [3] steps
# Total reward [1.2181355953216553]
# Total reward opponent [0]
# loss = 7.3899846
# step 1459: Survived [4] steps
# Total reward [2.233632802963257]
# Total reward opponent [0]
# step 1462: Survived [2] steps
# Total reward [0.48342108726501465]
# Total reward opponent [0]
# step 1463: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1465: Survived [1] steps
# Total reward [-0.22682690620422363]
# Total reward opponent [0]
# step 1466: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1469: Survived [2] steps
# Total reward [0.4924194812774658]
# Total reward opponent [0]
# step 1477: Survived [7] steps
# Total reward [4.601638674736023]
# Total reward opponent [0]
# step 1480: Survived [2] steps
# Total reward [0.44583117961883545]
# Total reward opponent [0]
# step 1485: Survived [4] steps
# Total reward [1.9902901649475098]
# Total reward opponent [0]
# step 1487: Survived [1] steps
# Total reward [-0.19095516204833984]
# Total reward opponent [0]
# step 1488: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1490: Survived [1] steps
# Total reward [-0.21874713897705078]
# Total reward opponent [0]
# step 1491: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 1492: disconnected 16
# step 1498: Survived [6] steps
# Total reward [3.646662950515747]
# Total reward opponent [0.7501740455627441]
# step 1500: Survived [1] steps
# Total reward [-0.24647808074951172]
# Total reward opponent [0]
# step 1503: Survived [2] steps
# Total reward [0.5019826889038086]
# Total reward opponent [0]
# ATTACK step 1504: disconnected 13
# step 1507: Survived [3] steps
# Total reward [1.3619651794433594]
# Total reward opponent [0.7647148370742798]
# step 1508: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1510: Survived [1] steps
# Total reward [-0.1963890790939331]
# Total reward opponent [0]
# loss = 15.281195
# step 1513: Survived [2] steps
# Total reward [0.391690731048584]
# Total reward opponent [0]
# step 1518: Survived [4] steps
# Total reward [1.9105497598648071]
# Total reward opponent [0]
# step 1521: Survived [2] steps
# Total reward [0.5676097869873047]
# Total reward opponent [0]
# step 1524: Survived [2] steps
# Total reward [0.4742194414138794]
# Total reward opponent [0]
# step 1528: Survived [3] steps
# Total reward [1.4040786027908325]
# Total reward opponent [0]
# step 1530: Survived [1] steps
# Total reward [-0.24410569667816162]
# Total reward opponent [0]
# step 1535: Survived [4] steps
# Total reward [2.0217387676239014]
# Total reward opponent [0]
# step 1539: Survived [3] steps
# Total reward [1.1673264503479004]
# Total reward opponent [0]
# step 1543: Survived [3] steps
# Total reward [1.294756293296814]
# Total reward opponent [0]
# step 1545: Survived [1] steps
# Total reward [-0.2235856056213379]
# Total reward opponent [0]
# ATTACK step 1546: disconnected 0
# ATTACK step 1547: disconnected 15
# ATTACK step 1548: disconnected 3
# step 1548: Survived [2] steps
# Total reward [2.3126111030578613]
# Total reward opponent [0.5391758680343628]
# ATTACK step 1549: disconnected 7
# step 1551: Survived [2] steps
# Total reward [0.5469980239868164]
# Total reward opponent [0.7561304569244385]
# ATTACK step 1553: disconnected 10
# step 1554: Survived [2] steps
# Total reward [0.503188967704773]
# Total reward opponent [0.6981427669525146]
# step 1555: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1558: Survived [2] steps
# Total reward [0.42677783966064453]
# Total reward opponent [0]
# step 1563: Survived [4] steps
# Total reward [1.9147180318832397]
# Total reward opponent [0]
# step 1565: Survived [1] steps
# Total reward [-0.2443164587020874]
# Total reward opponent [0]
# loss = 5.7203755
# step 1569: Survived [3] steps
# Total reward [1.304787039756775]
# Total reward opponent [0]
# ATTACK step 1575: disconnected 1
# step 1576: Survived [6] steps
# Total reward [3.728917360305786]
# Total reward opponent [0.7044534683227539]
# step 1578: Survived [1] steps
# Total reward [-0.21736621856689453]
# Total reward opponent [0]
# step 1584: Survived [5] steps
# Total reward [3.023233652114868]
# Total reward opponent [0]
# step 1589: Survived [4] steps
# Total reward [2.3283711671829224]
# Total reward opponent [0]
# step 1590: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1593: Survived [2] steps
# Total reward [0.5924923419952393]
# Total reward opponent [0]
# step 1594: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1600: Survived [5] steps
# Total reward [3.1110827922821045]
# Total reward opponent [0]
# step 1607: Survived [6] steps
# Total reward [3.5690265893936157]
# Total reward opponent [0]
# step 1610: Survived [2] steps
# Total reward [0.405606746673584]
# Total reward opponent [0]
# step 1616: Survived [5] steps
# Total reward [2.957209348678589]
# Total reward opponent [0]
# step 1622: Survived [5] steps
# Total reward [2.7533318996429443]
# Total reward opponent [0]
# loss = 6.259239
# step 1625: Survived [2] steps
# Total reward [0.4582374095916748]
# Total reward opponent [0]
# step 1626: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1627: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1632: Survived [4] steps
# Total reward [1.975083589553833]
# Total reward opponent [0]
# step 1633: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1635: Survived [1] steps
# Total reward [-0.23111915588378906]
# Total reward opponent [0]
# step 1638: Survived [2] steps
# Total reward [0.420674204826355]
# Total reward opponent [0]
# step 1640: Survived [1] steps
# Total reward [-0.2114393711090088]
# Total reward opponent [0]
# ATTACK step 1646: disconnected 2
# step 1646: Survived [5] steps
# Total reward [4.589612722396851]
# Total reward opponent [-1.0]
# step 1650: Survived [3] steps
# Total reward [1.4571051597595215]
# Total reward opponent [0]
# step 1651: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1653: Survived [1] steps
# Total reward [-0.23498642444610596]
# Total reward opponent [0]
# step 1654: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1655: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1656: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1662: Survived [5] steps
# Total reward [2.9586368799209595]
# Total reward opponent [0]
# step 1665: Survived [2] steps
# Total reward [0.4833657741546631]
# Total reward opponent [0]
# step 1668: Survived [2] steps
# Total reward [0.4995582103729248]
# Total reward opponent [0]
# step 1670: Survived [1] steps
# Total reward [-0.25342893600463867]
# Total reward opponent [0]
# step 1673: Survived [2] steps
# Total reward [0.5151054859161377]
# Total reward opponent [0]
# step 1676: Survived [2] steps
# Total reward [0.5488505363464355]
# Total reward opponent [0]
# ATTACK step 1678: disconnected 2
# step 1679: Survived [2] steps
# Total reward [0.5536824464797974]
# Total reward opponent [0.7609201669692993]
# loss = 8.320007
# step 1684: Survived [4] steps
# Total reward [2.0612900257110596]
# Total reward opponent [0]
# step 1687: Survived [2] steps
# Total reward [0.564861536026001]
# Total reward opponent [0]
# step 1688: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1689: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1693: Survived [3] steps
# Total reward [1.3310624361038208]
# Total reward opponent [0]
# step 1697: Survived [3] steps
# Total reward [1.473995566368103]
# Total reward opponent [0]
# ATTACK step 1698: disconnected 18
# step 1698: Survived [0] steps
# Total reward [0.792119026184082]
# Total reward opponent [-1.0]
# step 1702: Survived [3] steps
# Total reward [1.2468360662460327]
# Total reward opponent [0]
# step 1704: Survived [1] steps
# Total reward [-0.19989013671875]
# Total reward opponent [0]
# step 1710: Survived [5] steps
# Total reward [2.558459997177124]
# Total reward opponent [0]
# step 1716: Survived [5] steps
# Total reward [3.071403384208679]
# Total reward opponent [0]
# step 1717: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1720: Survived [2] steps
# Total reward [0.4921610355377197]
# Total reward opponent [0]
# step 1723: Survived [2] steps
# Total reward [0.4495244026184082]
# Total reward opponent [0]
# step 1729: Survived [5] steps
# Total reward [2.832961082458496]
# Total reward opponent [0]
# step 1730: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1731: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# loss = 6.435958
# step 1738: Survived [6] steps
# Total reward [3.161586046218872]
# Total reward opponent [0]
# step 1739: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# ATTACK step 1742: disconnected 0
# step 1743: Survived [3] steps
# Total reward [1.2599658966064453]
# Total reward opponent [0.7187703847885132]
# step 1744: Survived [0] steps
# Total reward [-1.0]
# Total reward opponent [0]
# step 1747: Survived [2] steps
# ...
# Total reward opponent [0.748079776763916]
# loss = 0.0044760997
# ATTACK step 19225: disconnected 19
# step 19230: Survived [22] steps
# Total reward [17.158371090888977]
# Total reward opponent [0.7889763116836548]
# ATTACK step 19236: disconnected 12
# step 19238: Survived [7] steps
# Total reward [4.601456999778748]
# Total reward opponent [0.781334638595581]
# ATTACK step 19253: disconnected 10
# loss = 0.0015311725
# ATTACK step 19269: disconnected 16
# step 19277: Survived [38] steps
# Total reward [29.763947129249573]
# Total reward opponent [1.6508047580718994]
# ATTACK step 19293: disconnected 7
# step 19295: Survived [17] steps
# Total reward [12.924261212348938]
# Total reward opponent [0.8028595447540283]
# ATTACK step 19296: disconnected 11
# step 19298: Survived [2] steps
# Total reward [0.639519453048706]
# Total reward opponent [0.8156214952468872]
# ATTACK step 19310: disconnected 10
# ATTACK step 19311: disconnected 16
# step 19318: Survived [19] steps
# Total reward [15.106235980987549]
# Total reward opponent [1.6586790084838867]
# ATTACK step 19319: disconnected 5
# loss = 0.0015479903
# step 19329: Survived [10] steps
# Total reward [7.178183197975159]
# Total reward opponent [0.8188085556030273]
# ATTACK step 19330: disconnected 17
# ATTACK step 19339: disconnected 10
# step 19339: Survived [9] steps
# Total reward [8.472265362739563]
# Total reward opponent [-0.1476447582244873]
# ATTACK step 19347: disconnected 16
# step 19357: Survived [17] steps
# Total reward [13.053927183151245]
# Total reward opponent [0.8319571018218994]
# ATTACK step 19373: disconnected 10
# loss = 0.0024892334
# ATTACK step 19390: disconnected 8
# step 19392: Survived [34] steps
# Total reward [27.365731239318848]
# Total reward opponent [1.6662111282348633]
# ATTACK step 19408: disconnected 6
# ATTACK step 19409: disconnected 17
# step 19413: Survived [20] steps
# Total reward [15.381954312324524]
# Total reward opponent [1.5562955141067505]
# ATTACK step 19425: disconnected 13
# loss = 0.0012631089
# ATTACK step 19442: disconnected 4
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# ATTACK step 19459: disconnected 1
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 126 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# step 19466: Survived [52] steps
# Total reward [35.41743344068527]
# Total reward opponent [2.454618811607361]
# step 19472: Survived [5] steps
# Total reward [2.9550479650497437]
# Total reward opponent [0]
# ATTACK step 19487: disconnected 8
# loss = 0.0023176663
# step 19488: Survived [15] steps
# Total reward [11.442185997962952]
# Total reward opponent [0.7841153144836426]
# step 19501: Survived [12] steps
# Total reward [8.633729100227356]
# Total reward opponent [0]
# ATTACK step 19517: disconnected 19
# step 19520: Survived [18] steps
# Total reward [13.608515620231628]
# Total reward opponent [0.7545249462127686]
# ATTACK step 19521: disconnected 11
# step 19523: Survived [2] steps
# Total reward [0.6322587728500366]
# Total reward opponent [0.8107014894485474]
# ATTACK step 19540: disconnected 8
# ATTACK step 19541: disconnected 19
# step 19541: Survived [17] steps
# Total reward [14.768540501594543]
# Total reward opponent [-0.1766136884689331]
# loss = 0.0025576493
# ATTACK step 19561: disconnected 7
# step 19563: Survived [21] steps
# Total reward [16.12564516067505]
# Total reward opponent [0.7977094650268555]
# ATTACK step 19582: disconnected 4
# ATTACK step 19596: disconnected 6
# step 19596: Survived [32] steps
# Total reward [27.40985333919525]
# Total reward opponent [-0.1579679250717163]
# loss = 0.0016156521
# ATTACK step 19615: disconnected 0
# ATTACK step 19619: disconnected 12
# ATTACK step 19620: disconnected 5
# step 19620: Survived [23] steps
# Total reward [19.500582456588745]
# Total reward opponent [0.6525130271911621]
# ATTACK step 19626: disconnected 13
# ATTACK step 19635: disconnected 17
# step 19637: Survived [16] steps
# Total reward [12.201072454452515]
# Total reward opponent [1.5930123329162598]
# loss = 0.0012361708
# ATTACK step 19656: disconnected 1
# step 19658: Survived [20] steps
# Total reward [15.252071738243103]
# Total reward opponent [0.769921064376831]
# ATTACK step 19660: disconnected 5
# ATTACK step 19662: disconnected 3
# step 19666: Survived [7] steps
# Total reward [4.398851633071899]
# Total reward opponent [1.5250002145767212]
# ATTACK step 19682: disconnected 19
# step 19682: Survived [15] steps
# Total reward [12.048713445663452]
# Total reward opponent [-1.0]
# ATTACK step 19688: disconnected 16
# ATTACK step 19698: disconnected 6
# loss = 0.0009788058
# ATTACK step 19718: disconnected 8
# step 19720: Survived [37] steps
# Total reward [29.16473913192749]
# Total reward opponent [2.418977975845337]
# ATTACK step 19734: disconnected 1
# ATTACK step 19738: disconnected 18
# step 19738: Survived [17] steps
# Total reward [14.700172543525696]
# Total reward opponent [-0.221915602684021]
# ATTACK step 19757: disconnected 1
# ATTACK step 19763: disconnected 17
# ATTACK step 19765: disconnected 13
# step 19766: Survived [27] steps
# Total reward [21.390029668807983]
# Total reward opponent [2.3502066135406494]
# loss = 0.0010800532
# ATTACK step 19768: disconnected 3
# ATTACK step 19772: disconnected 5
# step 19774: Survived [7] steps
# Total reward [4.328895688056946]
# Total reward opponent [1.4556612968444824]
# ATTACK step 19776: disconnected 16
# ATTACK step 19792: disconnected 10
# ATTACK step 19800: disconnected 18
# step 19800: Survived [25] steps
# Total reward [21.720950961112976]
# Total reward opponent [0.6492613554000854]
# ATTACK step 19811: disconnected 2
# step 19813: Survived [12] steps
# Total reward [8.632321953773499]
# Total reward opponent [0.7721762657165527]
# ATTACK step 19814: disconnected 4
# ATTACK step 19822: disconnected 11
# loss = 0.0012914089
# step 19829: Survived [15] steps
# Total reward [11.524034142494202]
# Total reward opponent [1.6687519550323486]
# ATTACK step 19848: disconnected 10
# ATTACK step 19867: disconnected 0
# step 19874: Survived [44] steps
# Total reward [35.56989085674286]
# Total reward opponent [1.7136062383651733]
# loss = 0.00095003296
# ATTACK step 19886: disconnected 7
# step 19888: Survived [13] steps
# Total reward [9.194288492202759]
# Total reward opponent [0.7771668434143066]
# step 19896: Survived [7] steps
# Total reward [4.584819912910461]
# Total reward opponent [0]
# ATTACK step 19913: disconnected 10
# ATTACK step 19933: disconnected 3
# loss = 0.0011631012
# ATTACK step 19947: disconnected 18
# step 19947: Survived [50] steps
# Total reward [43.93204212188721]
# Total reward opponent [0.7267905473709106]
# ATTACK step 19964: disconnected 15
# ATTACK step 19965: disconnected 14
# step 19967: Survived [19] steps
# Total reward [14.590363502502441]
# Total reward opponent [1.5279208421707153]
# ATTACK step 19970: disconnected 7
# step 19972: Survived [4] steps
# Total reward [2.21850848197937]
# Total reward opponent [0.770155668258667]
# ATTACK step 19985: disconnected 12
# ATTACK step 19986: disconnected 11
# step 19986: Survived [13] steps
# Total reward [11.381751656532288]
# Total reward opponent [-0.20579040050506592]
# ATTACK step 19991: disconnected 13
# loss = 0.0013126535
# Step [20000] -- Random [0.01]
# Successfully saved model at: saved_agent_DDDQN_random_opponent_20000/DDDQN.h5
# ATTACK step 20003: disconnected 19
# step 20005: Survived [18] steps
# Total reward [13.399795174598694]
# Total reward opponent [1.5399469137191772]
# ATTACK step 20007: disconnected 6
# ATTACK step 20009: disconnected 18
# step 20009: Survived [3] steps
# Total reward [3.2094496488571167]
# Total reward opponent [-0.2125236988067627]
# step 20022: Survived [12] steps
# Total reward [8.868446350097656]
# Total reward opponent [0]
# ATTACK step 20029: disconnected 16
# ATTACK step 20032: disconnected 13
# ATTACK step 20038: disconnected 9
# step 20038: Survived [15] steps
# Total reward [13.364408731460571]
# Total reward opponent [0.6612173318862915]
# ATTACK step 20041: disconnected 11
# step 20043: Survived [4] steps
# Total reward [1.981666922569275]
# Total reward opponent [0.7023115158081055]
# loss = 0.0017279411
# ATTACK step 20053: disconnected 15
# ATTACK step 20057: disconnected 14
# step 20057: Survived [13] steps
# Total reward [11.413511395454407]
# Total reward opponent [-0.20982742309570312]
# ATTACK step 20068: disconnected 7
# step 20070: Survived [12] steps
# Total reward [8.85093379020691]
# Total reward opponent [0.7888246774673462]
# ATTACK step 20081: disconnected 14
# step 20083: Survived [12] steps
# Total reward [9.07369089126587]
# Total reward opponent [0.8307805061340332]
# ATTACK step 20101: disconnected 10
# loss = 0.001030737
# step 20110: Survived [26] steps
# Total reward [19.85195755958557]
# Total reward opponent [0.8265490531921387]
# ATTACK step 20112: disconnected 18
# step 20112: Survived [1] steps
# Total reward [1.6391546726226807]
# Total reward opponent [-1.0]
# ATTACK step 20113: disconnected 3
# step 20119: Survived [6] steps
# Total reward [3.297567129135132]
# Total reward opponent [0.7632330656051636]
# ATTACK step 20136: disconnected 12
# step 20138: Survived [18] steps
# Total reward [14.194184303283691]
# Total reward opponent [0.810584545135498]
# step 20148: Survived [9] steps
# Total reward [6.326338171958923]
# Total reward opponent [0]
# ATTACK step 20154: disconnected 10
# loss = 0.00173656
# ATTACK step 20170: disconnected 5
# step 20174: Survived [25] steps
# Total reward [19.35284996032715]
# Total reward opponent [1.5943249464035034]
# step 20179: Survived [4] steps
# Total reward [2.253819704055786]
# Total reward opponent [0]
# step 20187: Survived [7] steps
# Total reward [4.299601435661316]
# Total reward opponent [0]
# step 20193: Survived [5] steps
# Total reward [2.998060703277588]
# Total reward opponent [0]
# ATTACK step 20200: disconnected 15
# ATTACK step 20201: disconnected 2
# step 20202: Survived [8] steps
# Total reward [5.324195861816406]
# Total reward opponent [1.4813543558120728]
# ATTACK step 20207: disconnected 18
# step 20207: Survived [4] steps
# Total reward [4.121635437011719]
# Total reward opponent [-1.0]
# ATTACK step 20208: disconnected 8
# step 20210: Survived [2] steps
# Total reward [0.5547575950622559]
# Total reward opponent [0.7663624286651611]
# loss = 0.0015493416
# ATTACK step 20220: disconnected 2
# step 20224: Survived [13] steps
# Total reward [9.686258554458618]
# Total reward opponent [0.8187801837921143]
# step 20232: Survived [7] steps
# Total reward [4.206245183944702]
# Total reward opponent [0]
# ATTACK step 20244: disconnected 14
# step 20246: Survived [13] steps
# Total reward [9.3363938331604]
# Total reward opponent [0.8110084533691406]
# step 20254: Survived [7] steps
# Total reward [4.290820837020874]
# Total reward opponent [0]
# Successfully saved model at: saved_agent_DDDQN_random_opponent_20000/DDDQN.h5

# %% [markdown]
# ## Evaluation

# %%
nb_episodesode = 10 # number of episodes to evaluate
log_path = './logs-evals'
nb_process = 1 # number of cores to use
max_iter = 150 # maximum number of steps per scenario
verbose = True
save_gif = False

# %%
env_name = "rte_case14_realistic"
env = make(env_name, reward_class=L2RPNSandBoxScore,
           other_rewards={
               "reward": L2RPNReward
           })

agent = DoubleDuelingDQN(env.observation_space, env.action_space, name='D3QN', is_training=False)
agent.load('./saved_agent_DDDQN_random_opponent_20000/DDDQN.h5')
    
runner_params = env.get_params_for_runner()
runner_params["verbose"] = False
runner = Runner(**runner_params, agentClass=None, agentInstance=agent)
    
res = runner.run(path_save=log_path, nb_episode=nb_episode, nb_process=nb_process, max_iter=150)
if verbose:
    print("Evaluation summary:")
    for _, chron_name, cum_reward, nb_time_step, max_ts in res:
        msg_tmp = "chronics at: {}".format(chron_name)
        msg_tmp += "\ttotal reward: {:.6f}".format(cum_reward)
        msg_tmp += "\ttime steps: {:.0f}/{:.0f}".format(nb_time_step,
                                                        max_ts)
        print(msg_tmp)

if save_gif:
    save_log_gif(log_path, res)
# Out:
# Agent action size: 141
# Successfully loaded network from: ./saved_agent_DDDQN_random_opponent_20000/DDDQN.h5
# Evaluation summary:
# chronics at: 000	total reward: 134757.593750	time steps: 23/150
# chronics at: 001	total reward: 55964.132812	time steps: 16/150
# chronics at: 002	total reward: 699308.500000	time steps: 78/150
# chronics at: 003	total reward: 97429.289062	time steps: 20/150
# chronics at: 004	total reward: 148633.250000	time steps: 24/150
# chronics at: 005	total reward: 179308.546875	time steps: 26/150
# chronics at: 006	total reward: 20127.648438	time steps: 14/150
# chronics at: 007	total reward: 179776.546875	time steps: 26/150
# chronics at: 008	total reward: 121001.671875	time steps: 22/150
# chronics at: 009	total reward: 1171.987549	time steps: 6/150
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-e0ba498fe810> in <module>
#      22         print(msg_tmp)
#      23
# ---> 24 if save_gif:
#      25     save_log_gif(log_path, res)
#
# NameError: name 'save_gif' is not defined
