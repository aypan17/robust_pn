# %%
import os
import json
import math
import numpy as np
import tensorflow as tf
import torch

import grid2op
from grid2op.Reward import *
from grid2op.Action import *

# %run d3qn.ipynb
# %run opponent.ipynb

# %%
def train_d3qn_against_no_opponent(env, agent, num_pre_training_steps, n_iter,
                                   save_path, log_path):
    # Make sure we can fill the experience buffer
    if num_pre_training_steps < agent.batch_size * agent.num_frames:
        num_pre_training_steps = agent.batch_size * agent.num_frames
        
    # Loop vars
    num_training_steps = n_iter
    num_steps = num_pre_training_steps + num_training_steps
    step = 0
    alive_steps = 0
    total_reward = 0
    agent.done = True
    print(f"Total number of steps: {num_steps}")

    # Create file system related vars
    logpath = os.path.join(log_path, agent.name)
    os.makedirs(save_path, exist_ok=True)
    modelpath = os.path.join(save_path, agent.name + ".h5")
    agent.tf_writer = tf.summary.create_file_writer(logpath, name=agent.name)
    agent._save_hyperparameters(save_path, env, num_steps)
    
    while step < num_steps:
        # Init first time or new episode
        if agent.done:
            new_obs = env.reset() # This shouldn't raise
            agent.reset(new_obs)
        if cfg.VERBOSE and step % 1000 == 0:
            print("Step [{}] -- Random [{}]".format(step, agent.epsilon))

        # Save current observation to stacking buffer
        agent._save_current_frame(agent.state)

        # Choose an action
        if step <= num_pre_training_steps:
            a = agent.Qmain.random_move()
        elif np.random.rand(1) < agent.epsilon:
            a = agent.Qmain.random_move()
        elif len(agent.frames) < agent.num_frames:
            a = 0 # Do nothing
        else:
            a, _ = agent.Qmain.predict_move(np.array(agent.frames))

        # Convert it to a valid action
        act = agent.convert_act(a)
        # Execute action
        new_obs, reward, agent.done, info = env.step(act)
        new_state = agent.convert_obs(new_obs)
        if info["is_illegal"] or info["is_ambiguous"] or \
           info["is_dispatching_illegal"] or info["is_illegal_reco"]:
            if cfg.VERBOSE:
                print (a, info)
        total_reward += reward

        # Save new observation to stacking buffer
        agent._save_next_frame(new_state)

        # Save to experience buffer
        if len(agent.frames2) == agent.num_frames:
            agent.per_buffer.add(np.array(agent.frames),
                                a, reward,
                                np.array(agent.frames2),
                                agent.done)

        # Perform training when we have enough experience in buffer
        if step >= num_pre_training_steps:
            training_step = step - num_pre_training_steps
            # Decay chance of random action
            agent.epsilon = agent._adaptive_epsilon_decay(training_step)

            # Perform training at given frequency
            if step % cfg.UPDATE_FREQ == 0 and \
               len(agent.per_buffer) >= agent.batch_size:
                # Perform training
                agent._batch_train(training_step, step)

                if cfg.UPDATE_TARGET_SOFT_TAU > 0.0:
                    tau = cfg.UPDATE_TARGET_SOFT_TAU
                    # Update target network towards primary network
                    agent.Qmain.update_target_soft(agent.Qtarget.model, tau)

            # Every UPDATE_TARGET_HARD_FREQ trainings, update target completely
            if cfg.UPDATE_TARGET_HARD_FREQ > 0 and \
               step % (cfg.UPDATE_FREQ * cfg.UPDATE_TARGET_HARD_FREQ) == 0:
                agent.Qmain.update_target_hard(agent.Qtarget.model)
        
        if agent.done:
            agent.epoch_rewards.append(total_reward)
            agent.epoch_alive.append(alive_steps)
            if cfg.VERBOSE and step > num_pre_training_steps:
                print("step {}: Survived [{}] steps".format(step, alive_steps))
                print("Total reward [{}]".format(total_reward))
            alive_steps = 0
            total_reward = 0
        else:
            alive_steps += 1
            
        ######## After Each Step #######
        if step > 0 and step % 2000 == 0: # save network every 5000 iters
            agent.save(modelpath)
        step += 1
        # Make new obs the current obs
        agent.obs = new_obs
        agent.state = new_state

    # Save model after all steps
    agent.save(modelpath)

# %%
# agent params
num_pre_training_steps = 256
learning_rate = 1e-4
initial_epsilon = 0.99
final_epsilon = 0.01
decay_epsilon = 20000

# training params
n_iter = 20000
env_name = "rte_case14_realistic"
env = make(env_name, reward_class=CombinedScaledReward)

# Register custom reward for training
cr = env._reward_helper.template_reward
#cr.addReward("overflow", CloseToOverflowReward(), 1.0)
cr.addReward("game", GameplayReward(), 1.0)
#cr.addReward("recolines", LinesReconnectedReward(), 1.0)
cr.addReward("l2rpn", L2RPNReward(), 2.0/float(env.n_line))
# Initialize custom rewards
cr.initialize(env)
# Set reward range to something managable
cr.set_range(-1.0, 1.0)

agent_name = "DDDQN"
save_path = "saved_agent_DDDQN_no_opponent_{}".format(n_iter)
log_path="tf_logs_DDDQN"

agent = DoubleDuelingDQN(env.observation_space, env.action_space, name=agent_name,
                         is_training=True, learning_rate=learning_rate,
                         initial_epsilon=initial_epsilon, final_epsilon=final_epsilon, decay_epsilon=decay_epsilon)

train_d3qn_against_no_opponent(env, agent, num_pre_training_steps, n_iter,
                                   save_path, log_path)
# Out:
# Agent action size: 141
# Total number of steps: 20256
# Step [0] -- Random [0.99]
# step 257: Survived [2] steps
# Total reward [0.4758448600769043]
# step 260: Survived [2] steps
# Total reward [0.5162427425384521]
# step 262: Survived [1] steps
# Total reward [-0.22687530517578125]
# step 263: Survived [0] steps
# Total reward [-1.0]
# step 269: Survived [5] steps
# Total reward [2.5897278785705566]
# loss = 6839.189
# step 280: Survived [10] steps
# Total reward [7.117826581001282]
# step 281: Survived [0] steps
# Total reward [-1.0]
# step 283: Survived [1] steps
# Total reward [-0.1944117546081543]
# step 285: Survived [1] steps
# Total reward [-0.15723586082458496]
# step 286: Survived [0] steps
# Total reward [-1.0]
# step 289: Survived [2] steps
# Total reward [0.4938105344772339]
# step 291: Survived [1] steps
# Total reward [-0.2002314329147339]
# step 294: Survived [2] steps
# Total reward [0.4412109851837158]
# step 300: Survived [5] steps
# Total reward [2.792956829071045]
# step 306: Survived [5] steps
# Total reward [2.829564690589905]
# step 308: Survived [1] steps
# Total reward [-0.2087879180908203]
# step 311: Survived [2] steps
# Total reward [0.4479527473449707]
# step 312: Survived [0] steps
# Total reward [-1.0]
# step 315: Survived [2] steps
# Total reward [0.5307292938232422]
# step 316: Survived [0] steps
# Total reward [-1.0]
# step 317: Survived [0] steps
# Total reward [-1.0]
# step 324: Survived [6] steps
# Total reward [3.558976411819458]
# step 327: Survived [2] steps
# Total reward [0.5918267965316772]
# step 329: Survived [1] steps
# Total reward [-0.2241528034210205]
# step 333: Survived [3] steps
# Total reward [1.1771773099899292]
# loss = 90.37365
# step 336: Survived [2] steps
# Total reward [0.10850644111633301]
# step 337: Survived [0] steps
# Total reward [-1.0]
# step 340: Survived [2] steps
# Total reward [0.5969810485839844]
# step 342: Survived [1] steps
# Total reward [-0.25351762771606445]
# step 345: Survived [2] steps
# Total reward [0.36682450771331787]
# step 347: Survived [1] steps
# Total reward [-0.2553229331970215]
# step 352: Survived [4] steps
# Total reward [2.2888550758361816]
# step 356: Survived [3] steps
# Total reward [1.2837610244750977]
# step 358: Survived [1] steps
# Total reward [-0.27446722984313965]
# step 362: Survived [3] steps
# Total reward [1.3610690832138062]
# step 367: Survived [4] steps
# Total reward [2.1641736030578613]
# step 371: Survived [3] steps
# Total reward [1.1244291067123413]
# step 372: Survived [0] steps
# Total reward [-1.0]
# step 374: Survived [1] steps
# Total reward [-0.17733335494995117]
# step 377: Survived [2] steps
# Total reward [0.4959545135498047]
# step 379: Survived [1] steps
# Total reward [-0.1664597988128662]
# step 382: Survived [2] steps
# Total reward [0.41900932788848877]
# step 385: Survived [2] steps
# Total reward [0.5553303956985474]
# step 390: Survived [4] steps
# Total reward [2.2100133895874023]
# loss = 151.22363
# step 393: Survived [2] steps
# Total reward [0.23299753665924072]
# step 394: Survived [0] steps
# Total reward [-1.0]
# step 400: Survived [5] steps
# Total reward [2.6953970193862915]
# step 401: Survived [0] steps
# Total reward [-1.0]
# step 410: Survived [8] steps
# Total reward [5.141340017318726]
# step 412: Survived [1] steps
# Total reward [-0.19443988800048828]
# step 413: Survived [0] steps
# Total reward [-1.0]
# step 415: Survived [1] steps
# Total reward [-0.26247596740722656]
# step 417: Survived [1] steps
# Total reward [-0.17550992965698242]
# step 419: Survived [1] steps
# Total reward [-0.2569577693939209]
# step 421: Survived [1] steps
# Total reward [-0.2831578254699707]
# step 423: Survived [1] steps
# Total reward [-0.20590662956237793]
# step 425: Survived [1] steps
# Total reward [-0.22142410278320312]
# step 428: Survived [2] steps
# Total reward [0.5039224624633789]
# step 430: Survived [1] steps
# Total reward [-0.28156960010528564]
# step 431: Survived [0] steps
# Total reward [-1.0]
# step 433: Survived [1] steps
# Total reward [-0.33639276027679443]
# step 438: Survived [4] steps
# Total reward [2.0580204725265503]
# step 441: Survived [2] steps
# Total reward [0.22938740253448486]
# step 442: Survived [0] steps
# Total reward [-1.0]
# loss = 104.85986
# step 451: Survived [8] steps
# Total reward [5.099449038505554]
# step 455: Survived [3] steps
# Total reward [1.162804365158081]
# step 456: Survived [0] steps
# Total reward [-1.0]
# step 461: Survived [4] steps
# Total reward [1.8605939149856567]
# step 463: Survived [1] steps
# Total reward [-0.19068026542663574]
# step 466: Survived [2] steps
# Total reward [0.40856266021728516]
# step 469: Survived [2] steps
# Total reward [0.5627768039703369]
# step 472: Survived [2] steps
# Total reward [0.5249847173690796]
# step 474: Survived [1] steps
# Total reward [-0.43395423889160156]
# step 476: Survived [1] steps
# Total reward [-0.1906571388244629]
# step 477: Survived [0] steps
# Total reward [-1.0]
# step 478: Survived [0] steps
# Total reward [-1.0]
# step 485: Survived [6] steps
# Total reward [3.257319450378418]
# step 487: Survived [1] steps
# Total reward [-0.24773085117340088]
# step 489: Survived [1] steps
# Total reward [-0.2778785228729248]
# step 490: Survived [0] steps
# Total reward [-1.0]
# step 491: Survived [0] steps
# Total reward [-1.0]
# step 499: Survived [7] steps
# Total reward [3.9732452630996704]
# step 500: Survived [0] steps
# Total reward [-1.0]
# step 502: Survived [1] steps
# Total reward [-0.2078474760055542]
# step 503: Survived [0] steps
# Total reward [-1.0]
# loss = 126.09122
# step 506: Survived [2] steps
# Total reward [0.5126174688339233]
# step 510: Survived [3] steps
# Total reward [1.1715900897979736]
# step 514: Survived [3] steps
# Total reward [1.4382685422897339]
# step 517: Survived [2] steps
# Total reward [0.5284321308135986]
# step 519: Survived [1] steps
# Total reward [-0.19903564453125]
# step 523: Survived [3] steps
# Total reward [1.0700408220291138]
# step 526: Survived [2] steps
# Total reward [0.581886887550354]
# step 530: Survived [3] steps
# Total reward [1.1216509342193604]
# step 531: Survived [0] steps
# Total reward [-1.0]
# step 534: Survived [2] steps
# Total reward [0.6148464679718018]
# step 538: Survived [3] steps
# Total reward [1.3514232635498047]
# step 539: Survived [0] steps
# Total reward [-1.0]
# step 541: Survived [1] steps
# Total reward [-0.4539833068847656]
# step 544: Survived [2] steps
# Total reward [0.5454249382019043]
# step 547: Survived [2] steps
# Total reward [0.4725346565246582]
# step 549: Survived [1] steps
# Total reward [-0.21063506603240967]
# step 550: Survived [0] steps
# Total reward [-1.0]
# step 551: Survived [0] steps
# Total reward [-1.0]
# step 556: Survived [4] steps
# Total reward [1.9543039798736572]
# step 559: Survived [2] steps
# Total reward [0.3343081474304199]
# loss = 190.12936
# step 562: Survived [2] steps
# Total reward [0.5246851444244385]
# step 566: Survived [3] steps
# Total reward [1.3661646842956543]
# step 569: Survived [2] steps
# Total reward [0.5498766899108887]
# step 573: Survived [3] steps
# Total reward [1.347795009613037]
# step 575: Survived [1] steps
# Total reward [-0.2263270616531372]
# step 576: Survived [0] steps
# Total reward [-1.0]
# step 578: Survived [1] steps
# Total reward [-0.1860506534576416]
# step 581: Survived [2] steps
# Total reward [0.2612985372543335]
# step 584: Survived [2] steps
# Total reward [0.410068154335022]
# step 585: Survived [0] steps
# Total reward [-1.0]
# step 588: Survived [2] steps
# Total reward [0.5274947881698608]
# step 592: Survived [3] steps
# Total reward [1.4811596870422363]
# step 595: Survived [2] steps
# Total reward [0.5710513591766357]
# step 598: Survived [2] steps
# Total reward [0.521355390548706]
# step 602: Survived [3] steps
# Total reward [1.350141167640686]
# step 604: Survived [1] steps
# Total reward [-0.24672317504882812]
# step 606: Survived [1] steps
# Total reward [-0.2812645435333252]
# step 607: Survived [0] steps
# Total reward [-1.0]
# step 609: Survived [1] steps
# Total reward [-0.2503781318664551]
# step 610: Survived [0] steps
# Total reward [-1.0]
# step 615: Survived [4] steps
# Total reward [2.2341445684432983]
# loss = 135.40733
# step 618: Survived [2] steps
# Total reward [0.526261568069458]
# step 619: Survived [0] steps
# Total reward [-1.0]
# step 622: Survived [2] steps
# Total reward [0.32510459423065186]
# step 626: Survived [3] steps
# Total reward [1.074911117553711]
# step 629: Survived [2] steps
# Total reward [0.590001106262207]
# step 634: Survived [4] steps
# Total reward [2.1108938455581665]
# step 637: Survived [2] steps
# Total reward [0.6626334190368652]
# step 638: Survived [0] steps
# Total reward [-1.0]
# step 641: Survived [2] steps
# Total reward [0.3148399591445923]
# step 644: Survived [2] steps
# Total reward [0.6524664163589478]
# step 646: Survived [1] steps
# Total reward [-0.23400557041168213]
# step 650: Survived [3] steps
# Total reward [1.2080037593841553]
# step 651: Survived [0] steps
# Total reward [-1.0]
# step 655: Survived [3] steps
# Total reward [1.3051862716674805]
# step 661: Survived [5] steps
# Total reward [2.8659268617630005]
# step 665: Survived [3] steps
# Total reward [1.4436231851577759]
# step 670: Survived [4] steps
# Total reward [2.187295436859131]
# step 671: Survived [0] steps
# Total reward [-1.0]
# loss = 103.28259
# step 672: Survived [0] steps
# Total reward [-1.0]
# step 677: Survived [4] steps
# Total reward [2.2079498767852783]
# step 681: Survived [3] steps
# Total reward [0.7469242215156555]
# step 682: Survived [0] steps
# Total reward [-1.0]
# step 684: Survived [1] steps
# Total reward [-0.2564300298690796]
# step 687: Survived [2] steps
# Total reward [0.4906657934188843]
# step 691: Survived [3] steps
# Total reward [1.2456443309783936]
# step 692: Survived [0] steps
# Total reward [-1.0]
# step 693: Survived [0] steps
# Total reward [-1.0]
# step 697: Survived [3] steps
# Total reward [1.2129802703857422]
# step 703: Survived [5] steps
# Total reward [2.906895399093628]
# step 704: Survived [0] steps
# Total reward [-1.0]
# step 711: Survived [6] steps
# Total reward [3.331299901008606]
# step 713: Survived [1] steps
# Total reward [-0.19985806941986084]
# step 715: Survived [1] steps
# Total reward [-0.22370052337646484]
# step 718: Survived [2] steps
# Total reward [0.5921434164047241]
# step 721: Survived [2] steps
# Total reward [0.436154842376709]
# step 724: Survived [2] steps
# Total reward [0.37434065341949463]
# step 726: Survived [1] steps
# Total reward [-0.22390484809875488]
# step 727: Survived [0] steps
# Total reward [-1.0]
# loss = 44.52539
# step 729: Survived [1] steps
# Total reward [-0.2333226203918457]
# step 732: Survived [2] steps
# Total reward [0.5118731260299683]
# step 733: Survived [0] steps
# Total reward [-1.0]
# step 735: Survived [1] steps
# Total reward [-0.26356494426727295]
# step 739: Survived [3] steps
# Total reward [1.4715075492858887]
# step 742: Survived [2] steps
# Total reward [0.5322761535644531]
# step 745: Survived [2] steps
# Total reward [0.5153193473815918]
# step 748: Survived [2] steps
# Total reward [0.5876984596252441]
# step 751: Survived [2] steps
# Total reward [0.45738303661346436]
# step 754: Survived [2] steps
# Total reward [0.3456428050994873]
# step 755: Survived [0] steps
# Total reward [-1.0]
# step 757: Survived [1] steps
# Total reward [-0.3540971279144287]
# step 761: Survived [3] steps
# Total reward [1.326242208480835]
# step 765: Survived [3] steps
# Total reward [1.408561110496521]
# step 768: Survived [2] steps
# Total reward [0.31568050384521484]
# step 771: Survived [2] steps
# Total reward [0.5105748176574707]
# step 772: Survived [0] steps
# Total reward [-1.0]
# step 774: Survived [1] steps
# Total reward [-0.2930924892425537]
# step 778: Survived [3] steps
# Total reward [1.2567335367202759]
# step 783: Survived [4] steps
# Total reward [1.9838985204696655]
# loss = 35.745388
# step 788: Survived [4] steps
# Total reward [1.8055498600006104]
# step 794: Survived [5] steps
# Total reward [2.986962676048279]
# step 796: Survived [1] steps
# Total reward [-0.18850171566009521]
# step 799: Survived [2] steps
# Total reward [0.3440808057785034]
# step 803: Survived [3] steps
# Total reward [1.075494408607483]
# step 810: Survived [6] steps
# Total reward [3.471541404724121]
# step 811: Survived [0] steps
# Total reward [-1.0]
# step 814: Survived [2] steps
# Total reward [0.44606924057006836]
# step 817: Survived [2] steps
# Total reward [0.4919079542160034]
# step 819: Survived [1] steps
# Total reward [-0.1800520420074463]
# step 820: Survived [0] steps
# Total reward [-1.0]
# step 824: Survived [3] steps
# Total reward [0.8385617733001709]
# step 825: Survived [0] steps
# Total reward [-1.0]
# step 832: Survived [6] steps
# Total reward [3.872713088989258]
# step 837: Survived [4] steps
# Total reward [2.1817022562026978]
# loss = 35.444992
# step 840: Survived [2] steps
# Total reward [0.4344747066497803]
# step 841: Survived [0] steps
# Total reward [-1.0]
# step 844: Survived [2] steps
# Total reward [0.4114041328430176]
# step 846: Survived [1] steps
# Total reward [-0.26024699211120605]
# step 847: Survived [0] steps
# Total reward [-1.0]
# step 848: Survived [0] steps
# Total reward [-1.0]
# step 852: Survived [3] steps
# Total reward [1.2649099826812744]
# step 855: Survived [2] steps
# Total reward [0.39829492568969727]
# step 860: Survived [4] steps
# Total reward [2.185667634010315]
# step 864: Survived [3] steps
# Total reward [1.2995163202285767]
# step 867: Survived [2] steps
# Total reward [0.5816152095794678]
# step 869: Survived [1] steps
# Total reward [-0.17166781425476074]
# step 873: Survived [3] steps
# Total reward [1.1070210933685303]
# step 876: Survived [2] steps
# Total reward [0.6376218795776367]
# step 879: Survived [2] steps
# Total reward [0.2745988368988037]
# step 882: Survived [2] steps
# Total reward [0.5766729116439819]
# step 884: Survived [1] steps
# Total reward [-0.20226120948791504]
# step 887: Survived [2] steps
# Total reward [0.5673327445983887]
# step 890: Survived [2] steps
# Total reward [0.5313621759414673]
# step 893: Survived [2] steps
# Total reward [0.6073429584503174]
# loss = 30.946995
# step 896: Survived [2] steps
# Total reward [0.3054232597351074]
# step 897: Survived [0] steps
# Total reward [-1.0]
# step 898: Survived [0] steps
# Total reward [-1.0]
# step 901: Survived [2] steps
# Total reward [0.6634746789932251]
# step 906: Survived [4] steps
# Total reward [1.9574129581451416]
# step 908: Survived [1] steps
# Total reward [-0.23734116554260254]
# step 911: Survived [2] steps
# Total reward [0.5275081396102905]
# step 913: Survived [1] steps
# Total reward [-0.20380234718322754]
# step 916: Survived [2] steps
# Total reward [0.23742616176605225]
# step 917: Survived [0] steps
# Total reward [-1.0]
# step 921: Survived [3] steps
# Total reward [1.0023127794265747]
# step 922: Survived [0] steps
# Total reward [-1.0]
# step 928: Survived [5] steps
# Total reward [2.4278074502944946]
# step 931: Survived [2] steps
# Total reward [0.4897727966308594]
# step 934: Survived [2] steps
# Total reward [0.5383105278015137]
# step 935: Survived [0] steps
# Total reward [-1.0]
# step 936: Survived [0] steps
# Total reward [-1.0]
# step 949: Survived [12] steps
# Total reward [8.320734024047852]
# step 951: Survived [1] steps
# Total reward [-0.21907544136047363]
# loss = 17.450043
# step 952: Survived [0] steps
# Total reward [-1.0]
# step 955: Survived [2] steps
# Total reward [0.6331323385238647]
# step 958: Survived [2] steps
# Total reward [0.4776766300201416]
# step 962: Survived [3] steps
# Total reward [1.4608097076416016]
# step 964: Survived [1] steps
# Total reward [-0.18575811386108398]
# step 968: Survived [3] steps
# Total reward [1.3851243257522583]
# step 971: Survived [2] steps
# Total reward [0.5837087631225586]
# step 975: Survived [3] steps
# Total reward [1.2686847448349]
# step 977: Survived [1] steps
# Total reward [-0.21732032299041748]
# step 978: Survived [0] steps
# Total reward [-1.0]
# step 983: Survived [4] steps
# Total reward [2.260066866874695]
# step 986: Survived [2] steps
# Total reward [0.5810190439224243]
# step 987: Survived [0] steps
# Total reward [-1.0]
# step 989: Survived [1] steps
# Total reward [-0.25351786613464355]
# step 992: Survived [2] steps
# Total reward [0.44115734100341797]
# step 993: Survived [0] steps
# Total reward [-1.0]
# step 994: Survived [0] steps
# Total reward [-1.0]
# step 999: Survived [4] steps
# Total reward [1.9050838947296143]
# Step [1000] -- Random [0.8949981880496173]
# step 1004: Survived [4] steps
# Total reward [2.0908602476119995]
# step 1007: Survived [2] steps
# Total reward [0.5624529123306274]
# loss = 18.10609
# step 1010: Survived [2] steps
# Total reward [0.11389589309692383]
# step 1014: Survived [3] steps
# Total reward [1.295823574066162]
# step 1015: Survived [0] steps
# Total reward [-1.0]
# step 1016: Survived [0] steps
# Total reward [-1.0]
# step 1018: Survived [1] steps
# Total reward [-0.20268285274505615]
# step 1019: Survived [0] steps
# Total reward [-1.0]
# step 1021: Survived [1] steps
# Total reward [-0.1512916088104248]
# step 1022: Survived [0] steps
# Total reward [-1.0]
# step 1025: Survived [2] steps
# Total reward [0.5453656911849976]
# step 1030: Survived [4] steps
# Total reward [1.9883209466934204]
# step 1036: Survived [5] steps
# Total reward [2.8560553789138794]
# step 1037: Survived [0] steps
# Total reward [-1.0]
# step 1041: Survived [3] steps
# Total reward [1.3659497499465942]
# step 1044: Survived [2] steps
# Total reward [0.463711142539978]
# step 1049: Survived [4] steps
# Total reward [2.2953548431396484]
# step 1054: Survived [4] steps
# Total reward [1.9092825651168823]
# step 1055: Survived [0] steps
# Total reward [-1.0]
# step 1060: Survived [4] steps
# Total reward [1.7924312353134155]
# step 1063: Survived [2] steps
# Total reward [0.2592122554779053]
# loss = 21.177113
# step 1066: Survived [2] steps
# Total reward [0.6230053901672363]
# step 1068: Survived [1] steps
# Total reward [-0.18503832817077637]
# step 1071: Survived [2] steps
# Total reward [0.46353018283843994]
# step 1074: Survived [2] steps
# Total reward [0.36610865592956543]
# step 1083: Survived [8] steps
# Total reward [5.614491820335388]
# step 1084: Survived [0] steps
# Total reward [-1.0]
# step 1087: Survived [2] steps
# Total reward [0.545758843421936]
# step 1090: Survived [2] steps
# Total reward [0.5624293088912964]
# step 1093: Survived [2] steps
# Total reward [0.450115442276001]
# step 1098: Survived [4] steps
# Total reward [2.024776339530945]
# step 1100: Survived [1] steps
# Total reward [-0.24429583549499512]
# step 1108: Survived [7] steps
# Total reward [3.907163977622986]
# step 1109: Survived [0] steps
# Total reward [-1.0]
# step 1110: Survived [0] steps
# Total reward [-1.0]
# step 1111: Survived [0] steps
# Total reward [-1.0]
# step 1113: Survived [1] steps
# Total reward [-0.270707368850708]
# step 1116: Survived [2] steps
# Total reward [0.39450550079345703]
# step 1117: Survived [0] steps
# Total reward [-1.0]
# loss = 26.505074
# step 1122: Survived [4] steps
# Total reward [2.1859920024871826]
# step 1127: Survived [4] steps
# Total reward [1.868389368057251]
# step 1131: Survived [3] steps
# Total reward [1.2988953590393066]
# step 1132: Survived [0] steps
# Total reward [-1.0]
# step 1135: Survived [2] steps
# Total reward [0.5378497838973999]
# step 1139: Survived [3] steps
# Total reward [1.1470112800598145]
# step 1142: Survived [2] steps
# Total reward [0.48886191844940186]
# step 1144: Survived [1] steps
# Total reward [-0.28687119483947754]
# step 1148: Survived [3] steps
# Total reward [1.4067304134368896]
# step 1152: Survived [3] steps
# Total reward [1.3948328495025635]
# step 1154: Survived [1] steps
# Total reward [-0.23110473155975342]
# step 1155: Survived [0] steps
# Total reward [-1.0]
# step 1159: Survived [3] steps
# Total reward [1.4319567680358887]
# step 1161: Survived [1] steps
# Total reward [-0.2571324110031128]
# step 1162: Survived [0] steps
# Total reward [-1.0]
# step 1164: Survived [1] steps
# Total reward [-0.2321605682373047]
# step 1166: Survived [1] steps
# Total reward [-0.27414870262145996]
# step 1170: Survived [3] steps
# Total reward [1.3685847520828247]
# step 1171: Survived [0] steps
# Total reward [-1.0]
# step 1174: Survived [2] steps
# Total reward [0.5248868465423584]
# loss = 26.298296
# step 1180: Survived [5] steps
# Total reward [2.903301477432251]
# step 1183: Survived [2] steps
# Total reward [0.6116375923156738]
# step 1184: Survived [0] steps
# Total reward [-1.0]
# step 1186: Survived [1] steps
# Total reward [-0.24925339221954346]
# step 1188: Survived [1] steps
# Total reward [-0.2265540361404419]
# step 1191: Survived [2] steps
# Total reward [0.6851446628570557]
# step 1194: Survived [2] steps
# Total reward [0.3637181520462036]
# step 1200: Survived [5] steps
# Total reward [2.9004772901535034]
# step 1202: Survived [1] steps
# Total reward [-0.2538578510284424]
# step 1208: Survived [5] steps
# Total reward [2.5373969078063965]
# step 1211: Survived [2] steps
# Total reward [0.3646625280380249]
# step 1213: Survived [1] steps
# Total reward [-0.23583078384399414]
# step 1214: Survived [0] steps
# Total reward [-1.0]
# step 1218: Survived [3] steps
# Total reward [1.1520099639892578]
# step 1220: Survived [1] steps
# Total reward [-0.1818101406097412]
# step 1223: Survived [2] steps
# Total reward [0.37531375885009766]
# step 1226: Survived [2] steps
# Total reward [0.4480278491973877]
# step 1230: Survived [3] steps
# Total reward [1.3239870071411133]
# loss = 78.19319
# step 1233: Survived [2] steps
# Total reward [0.619407057762146]
# step 1238: Survived [4] steps
# Total reward [2.1656707525253296]
# step 1241: Survived [2] steps
# Total reward [0.5938541889190674]
# step 1243: Survived [1] steps
# Total reward [-0.20433902740478516]
# step 1246: Survived [2] steps
# Total reward [0.4759182929992676]
# step 1248: Survived [1] steps
# Total reward [-0.23551666736602783]
# step 1249: Survived [0] steps
# Total reward [-1.0]
# step 1251: Survived [1] steps
# Total reward [-0.22127318382263184]
# step 1253: Survived [1] steps
# Total reward [-0.19424009323120117]
# step 1255: Survived [1] steps
# Total reward [-0.25516295433044434]
# step 1257: Survived [1] steps
# Total reward [-0.21315217018127441]
# step 1261: Survived [3] steps
# Total reward [1.2010575532913208]
# step 1266: Survived [4] steps
# Total reward [1.8764804601669312]
# step 1271: Survived [4] steps
# Total reward [2.1512012481689453]
# step 1273: Survived [1] steps
# Total reward [-0.23221969604492188]
# step 1280: Survived [6] steps
# Total reward [3.6860873699188232]
# step 1284: Survived [3] steps
# Total reward [1.4904522895812988]
# loss = 27.990965
# step 1288: Survived [3] steps
# Total reward [1.2601567506790161]
# step 1289: Survived [0] steps
# Total reward [-1.0]
# step 1293: Survived [3] steps
# Total reward [1.2270969152450562]
# step 1298: Survived [4] steps
# Total reward [1.878342628479004]
# step 1300: Survived [1] steps
# Total reward [-0.1833655834197998]
# step 1303: Survived [2] steps
# Total reward [0.5421103239059448]
# step 1309: Survived [5] steps
# Total reward [2.969893217086792]
# step 1313: Survived [3] steps
# Total reward [1.2831857204437256]
# step 1317: Survived [3] steps
# Total reward [1.419041633605957]
# step 1318: Survived [0] steps
# Total reward [-1.0]
# step 1321: Survived [2] steps
# Total reward [0.5493650436401367]
# step 1325: Survived [3] steps
# Total reward [1.22184419631958]
# step 1329: Survived [3] steps
# Total reward [1.2319974899291992]
# step 1331: Survived [1] steps
# Total reward [-0.2584805488586426]
# step 1332: Survived [0] steps
# Total reward [-1.0]
# step 1335: Survived [2] steps
# Total reward [0.4234168529510498]
# step 1338: Survived [2] steps
# Total reward [0.5861181020736694]
# step 1340: Survived [1] steps
# Total reward [-0.2060633897781372]
# step 1341: Survived [0] steps
# Total reward [-1.0]
# loss = 33.481415
# step 1346: Survived [4] steps
# Total reward [2.035455346107483]
# step 1349: Survived [2] steps
# Total reward [0.49671411514282227]
# step 1352: Survived [2] steps
# Total reward [0.6210622787475586]
# step 1355: Survived [2] steps
# Total reward [0.5897128582000732]
# step 1359: Survived [3] steps
# Total reward [1.4449050426483154]
# step 1361: Survived [1] steps
# Total reward [-0.2312030792236328]
# step 1365: Survived [3] steps
# Total reward [1.2458271980285645]
# step 1369: Survived [3] steps
# Total reward [1.3082592487335205]
# step 1371: Survived [1] steps
# Total reward [-0.18273425102233887]
# step 1373: Survived [1] steps
# Total reward [-0.28509020805358887]
# step 1377: Survived [3] steps
# Total reward [1.2799499034881592]
# step 1381: Survived [3] steps
# Total reward [1.2959446907043457]
# step 1383: Survived [1] steps
# Total reward [-0.17361164093017578]
# step 1384: Survived [0] steps
# Total reward [-1.0]
# step 1386: Survived [1] steps
# Total reward [-0.1972339153289795]
# step 1387: Survived [0] steps
# Total reward [-1.0]
# step 1388: Survived [0] steps
# Total reward [-1.0]
# step 1392: Survived [3] steps
# Total reward [1.3196310997009277]
# step 1394: Survived [1] steps
# Total reward [-0.1978163719177246]
# loss = 34.4841
# step 1402: Survived [7] steps
# Total reward [4.490212559700012]
# step 1406: Survived [3] steps
# Total reward [1.2837529182434082]
# step 1407: Survived [0] steps
# Total reward [-1.0]
# step 1411: Survived [3] steps
# Total reward [0.9685314893722534]
# step 1414: Survived [2] steps
# Total reward [0.44484829902648926]
# step 1424: Survived [9] steps
# Total reward [5.890481472015381]
# step 1428: Survived [3] steps
# Total reward [1.38614022731781]
# step 1429: Survived [0] steps
# Total reward [-1.0]
# step 1432: Survived [2] steps
# Total reward [0.3649568557739258]
# step 1433: Survived [0] steps
# Total reward [-1.0]
# step 1437: Survived [3] steps
# Total reward [1.168925404548645]
# step 1442: Survived [4] steps
# Total reward [2.151926875114441]
# step 1447: Survived [4] steps
# Total reward [2.0646060705184937]
# step 1449: Survived [1] steps
# Total reward [-0.3160921335220337]
# step 1452: Survived [2] steps
# Total reward [0.47760283946990967]
# loss = 20.266653
# step 1456: Survived [3] steps
# Total reward [1.2421305179595947]
# step 1457: Survived [0] steps
# Total reward [-1.0]
# step 1460: Survived [2] steps
# Total reward [0.4466984272003174]
# step 1462: Survived [1] steps
# Total reward [-0.18335425853729248]
# step 1463: Survived [0] steps
# Total reward [-1.0]
# step 1464: Survived [0] steps
# Total reward [-1.0]
# step 1468: Survived [3] steps
# Total reward [1.3160704374313354]
# step 1471: Survived [2] steps
# Total reward [0.5843439102172852]
# step 1475: Survived [3] steps
# Total reward [1.313818335533142]
# step 1479: Survived [3] steps
# Total reward [1.3316068649291992]
# step 1481: Survived [1] steps
# Total reward [-0.1960461139678955]
# step 1483: Survived [1] steps
# Total reward [-0.24216532707214355]
# step 1486: Survived [2] steps
# Total reward [0.4181939363479614]
# step 1487: Survived [0] steps
# Total reward [-1.0]
# step 1490: Survived [2] steps
# Total reward [0.6160440444946289]
# step 1492: Survived [1] steps
# Total reward [-0.2253873348236084]
# step 1496: Survived [3] steps
# Total reward [1.165168285369873]
# step 1498: Survived [1] steps
# Total reward [-0.23102641105651855]
# step 1501: Survived [2] steps
# Total reward [0.43239903450012207]
# step 1505: Survived [3] steps
# Total reward [1.3587781190872192]
# step 1506: Survived [0] steps
# Total reward [-1.0]
# step 1508: Survived [1] steps
# Total reward [-0.27205121517181396]
# loss = 20.779564
# step 1512: Survived [3] steps
# Total reward [1.2344199419021606]
# step 1515: Survived [2] steps
# Total reward [0.4062666893005371]
# step 1517: Survived [1] steps
# Total reward [-0.19768428802490234]
# step 1518: Survived [0] steps
# Total reward [-1.0]
# step 1520: Survived [1] steps
# Total reward [-0.21585464477539062]
# step 1522: Survived [1] steps
# Total reward [-0.23470962047576904]
# step 1523: Survived [0] steps
# Total reward [-1.0]
# step 1526: Survived [2] steps
# Total reward [0.5575425624847412]
# step 1528: Survived [1] steps
# Total reward [-0.2146749496459961]
# step 1530: Survived [1] steps
# Total reward [-0.203363299369812]
# step 1538: Survived [7] steps
# Total reward [4.536854982376099]
# step 1540: Survived [1] steps
# Total reward [-0.2703261375427246]
# step 1543: Survived [2] steps
# Total reward [0.47342944145202637]
# step 1546: Survived [2] steps
# Total reward [0.6062874794006348]
# step 1547: Survived [0] steps
# Total reward [-1.0]
# step 1551: Survived [3] steps
# Total reward [0.8651912212371826]
# step 1552: Survived [0] steps
# Total reward [-1.0]
# step 1556: Survived [3] steps
# Total reward [1.5090701580047607]
# step 1559: Survived [2] steps
# Total reward [0.6149904727935791]
# step 1563: Survived [3] steps
# Total reward [1.3409888744354248]
# step 1565: Survived [1] steps
# Total reward [-0.3116786479949951]
# step 1566: Survived [0] steps
# Total reward [-1.0]
# loss = 36.109398
# step 1569: Survived [2] steps
# Total reward [0.6019117832183838]
# step 1574: Survived [4] steps
# Total reward [2.0960018634796143]
# step 1577: Survived [2] steps
# Total reward [0.42908501625061035]
# step 1578: Survived [0] steps
# Total reward [-1.0]
# step 1581: Survived [2] steps
# Total reward [0.587460994720459]
# step 1583: Survived [1] steps
# Total reward [-0.23030543327331543]
# step 1584: Survived [0] steps
# Total reward [-1.0]
# step 1587: Survived [2] steps
# Total reward [0.45311474800109863]
# step 1590: Survived [2] steps
# Total reward [0.5610947608947754]
# step 1592: Survived [1] steps
# Total reward [-0.2056868076324463]
# step 1596: Survived [3] steps
# Total reward [1.24581778049469]
# step 1598: Survived [1] steps
# Total reward [-0.2081923484802246]
# step 1600: Survived [1] steps
# Total reward [-0.27784276008605957]
# step 1602: Survived [1] steps
# Total reward [-0.1862800121307373]
# step 1606: Survived [3] steps
# Total reward [0.8938536643981934]
# step 1607: Survived [0] steps
# Total reward [-1.0]
# step 1609: Survived [1] steps
# Total reward [-0.23586201667785645]
# step 1612: Survived [2] steps
# Total reward [0.5033752918243408]
# step 1613: Survived [0] steps
# Total reward [-1.0]
# step 1617: Survived [3] steps
# Total reward [1.0779417753219604]
# step 1620: Survived [2] steps
# Total reward [0.5023455619812012]
# loss = 18.209286
# step 1624: Survived [3] steps
# Total reward [1.384643316268921]
# step 1626: Survived [1] steps
# Total reward [-0.2760826349258423]
# step 1629: Survived [2] steps
# Total reward [0.3491705656051636]
# step 1631: Survived [1] steps
# Total reward [-0.255352258682251]
# step 1634: Survived [2] steps
# Total reward [0.49043726921081543]
# step 1639: Survived [4] steps
# Total reward [2.0540547370910645]
# step 1641: Survived [1] steps
# Total reward [-0.22913014888763428]
# step 1646: Survived [4] steps
# Total reward [2.235255479812622]
# step 1648: Survived [1] steps
# Total reward [-0.2479315996170044]
# step 1650: Survived [1] steps
# Total reward [-0.18326091766357422]
# step 1654: Survived [3] steps
# Total reward [1.376330852508545]
# step 1657: Survived [2] steps
# Total reward [0.5175271034240723]
# step 1666: Survived [8] steps
# Total reward [5.369492173194885]
# step 1668: Survived [1] steps
# Total reward [-0.17933416366577148]
# step 1670: Survived [1] steps
# Total reward [-0.2077716588973999]
# step 1676: Survived [5] steps
# Total reward [2.869391679763794]
# loss = 27.72076
# step 1682: Survived [5] steps
# Total reward [2.994844079017639]
# step 1685: Survived [2] steps
# Total reward [0.3956336975097656]
# step 1689: Survived [3] steps
# Total reward [1.3725264072418213]
# step 1690: Survived [0] steps
# Total reward [-1.0]
# step 1694: Survived [3] steps
# Total reward [1.1597447395324707]
# step 1702: Survived [7] steps
# Total reward [4.474727392196655]
# step 1703: Survived [0] steps
# Total reward [-1.0]
# step 1708: Survived [4] steps
# Total reward [1.9100332260131836]
# step 1710: Survived [1] steps
# Total reward [-0.1812915802001953]
# step 1715: Survived [4] steps
# Total reward [2.1173465251922607]
# step 1718: Survived [2] steps
# Total reward [0.5305076837539673]
# step 1721: Survived [2] steps
# Total reward [0.4465811252593994]
# step 1723: Survived [1] steps
# Total reward [-0.20667219161987305]
# step 1732: Survived [8] steps
# Total reward [5.320469975471497]
# loss = 9.529205
# step 1737: Survived [4] steps
# Total reward [2.0571861267089844]
# step 1740: Survived [2] steps
# Total reward [0.5738265514373779]
# step 1744: Survived [3] steps
# Total reward [1.214788794517517]
# step 1746: Survived [1] steps
# Total reward [-0.23873627185821533]
# step 1747: Survived [0] steps
# Total reward [-1.0]
# step 1750: Survived [2] steps
# Total reward [0.473885178565979]
# step 1754: Survived [3] steps
# Total reward [1.3130223751068115]
# step 1757: Survived [2] steps
# Total reward [0.5336134433746338]
# step 1758: Survived [0] steps
# Total reward [-1.0]
# step 1759: Survived [0] steps
# Total reward [-1.0]
# step 1760: Survived [0] steps
# Total reward [-1.0]
# step 1762: Survived [1] steps
# Total reward [-0.2892754077911377]
# step 1764: Survived [1] steps
# Total reward [-0.2272334098815918]
# step 1767: Survived [2] steps
# Total reward [0.5428134202957153]
# step 1773: Survived [5] steps
# Total reward [2.9944052696228027]
# step 1776: Survived [2] steps
# Total reward [0.6119174957275391]
# step 1779: Survived [2] steps
# Total reward [0.4281342029571533]
# step 1783: Survived [3] steps
# Total reward [1.4331715106964111]
# step 1786: Survived [2] steps
# Total reward [0.6768150329589844]
# step 1790: Survived [3] steps
# Total reward [1.2120821475982666]
# loss = 12.351147
# step 1796: Survived [5] steps
# Total reward [2.7754637002944946]
# step 1803: Survived [6] steps
# Total reward [3.83986234664917]
# step 1806: Survived [2] steps
# Total reward [0.4800461530685425]
# step 1808: Survived [1] steps
# Total reward [-0.21791410446166992]
# step 1815: Survived [6] steps
# Total reward [3.544421076774597]
# step 1818: Survived [2] steps
# Total reward [0.4353785514831543]
# step 1823: Survived [4] steps
# Total reward [2.194844126701355]
# step 1826: Survived [2] steps
# Total reward [0.54068922996521]
# step 1835: Survived [8] steps
# Total reward [5.29441511631012]
# step 1839: Survived [3] steps
# Total reward [1.202141523361206]
# step 1842: Survived [2] steps
# Total reward [0.530882716178894]
# step 1844: Survived [1] steps
# Total reward [-0.17903399467468262]
# step 1846: Survived [1] steps
# Total reward [-0.17377448081970215]
# loss = 13.484483
# step 1848: Survived [1] steps
# Total reward [-0.2337939739227295]
# step 1853: Survived [4] steps
# Total reward [2.1071972846984863]
# step 1855: Survived [1] steps
# Total reward [-0.181196928024292]
# step 1863: Survived [7] steps
# Total reward [4.44002377986908]
# step 1864: Survived [0] steps
# Total reward [-1.0]
# step 1867: Survived [2] steps
# Total reward [0.43021678924560547]
# step 1871: Survived [3] steps
# Total reward [1.2044025659561157]
# step 1875: Survived [3] steps
# Total reward [1.3048458099365234]
# step 1878: Survived [2] steps
# Total reward [0.06549906730651855]
# step 1881: Survived [2] steps
# Total reward [0.5098645687103271]
# step 1884: Survived [2] steps
# Total reward [0.47810590267181396]
# step 1889: Survived [4] steps
# Total reward [2.085319757461548]
# step 1892: Survived [2] steps
# Total reward [0.41849982738494873]
# step 1896: Survived [3] steps
# Total reward [1.3851933479309082]
# step 1900: Survived [3] steps
# Total reward [1.0379966497421265]
# step 1903: Survived [2] steps
# Total reward [0.5065994262695312]
# loss = 18.506157
# step 1904: Survived [0] steps
# Total reward [-1.0]
# step 1906: Survived [1] steps
# Total reward [-0.19312036037445068]
# step 1909: Survived [2] steps
# Total reward [0.45045459270477295]
# step 1913: Survived [3] steps
# Total reward [1.3534340858459473]
# step 1916: Survived [2] steps
# Total reward [0.540579080581665]
# step 1919: Survived [2] steps
# Total reward [0.561005711555481]
# step 1922: Survived [2] steps
# Total reward [0.5336786508560181]
# step 1924: Survived [1] steps
# Total reward [-0.15870368480682373]
# step 1931: Survived [6] steps
# Total reward [4.09980571269989]
# step 1935: Survived [3] steps
# Total reward [1.364485740661621]
# step 1936: Survived [0] steps
# Total reward [-1.0]
# step 1939: Survived [2] steps
# Total reward [0.43410778045654297]
# step 1945: Survived [5] steps
# Total reward [2.8989944458007812]
# step 1946: Survived [0] steps
# Total reward [-1.0]
# step 1947: Survived [0] steps
# Total reward [-1.0]
# step 1952: Survived [4] steps
# Total reward [2.1041600704193115]
# step 1959: Survived [6] steps
# Total reward [3.5573095083236694]
# loss = 12.348009
# step 1964: Survived [4] steps
# Total reward [2.0310174226760864]
# step 1967: Survived [2] steps
# Total reward [0.41852712631225586]
# step 1972: Survived [4] steps
# Total reward [1.968247413635254]
# step 1973: Survived [0] steps
# Total reward [-1.0]
# step 1976: Survived [2] steps
# Total reward [0.5379506349563599]
# step 1979: Survived [2] steps
# Total reward [0.5322500467300415]
# step 1981: Survived [1] steps
# Total reward [-0.23573720455169678]
# step 1983: Survived [1] steps
# Total reward [-0.2053896188735962]
# step 1988: Survived [4] steps
# Total reward [2.1387475728988647]
# step 1991: Survived [2] steps
# Total reward [0.5373150110244751]
# step 1995: Survived [3] steps
# Total reward [1.4197256565093994]
# step 1998: Survived [2] steps
# Total reward [0.5750753879547119]
# Step [2000] -- Random [0.7613959723485773]
# Successfully saved model at: saved_agent_DDDQN_no_opponent_20000/DDDQN.h5
# step 2004: Survived [5] steps
# Total reward [3.0090389251708984]
# step 2010: Survived [5] steps
# Total reward [2.6210864782333374]
# step 2013: Survived [2] steps
# Total reward [0.4007420539855957]
# loss = 8.60548
# step 2017: Survived [3] steps
# Total reward [1.334800362586975]
# step 2020: Survived [2] steps
# Total reward [0.4345637559890747]
# step 2023: Survived [2] steps
# Total reward [0.4140357971191406]
# step 2024: Survived [0] steps
# Total reward [-1.0]
# step 2027: Survived [2] steps
# Total reward [0.5833624601364136]
# step 2029: Survived [1] steps
# Total reward [-0.21997928619384766]
# step 2039: Survived [9] steps
# Total reward [5.898274183273315]
# step 2043: Survived [3] steps
# Total reward [1.359342098236084]
# step 2046: Survived [2] steps
# Total reward [0.5046672821044922]
# step 2048: Survived [1] steps
# Total reward [-0.2229156494140625]
# step 2052: Survived [3] steps
# Total reward [1.4371229410171509]
# step 2056: Survived [3] steps
# Total reward [1.3967540264129639]
# step 2057: Survived [0] steps
# Total reward [-1.0]
# step 2059: Survived [1] steps
# Total reward [-0.24114012718200684]
# step 2062: Survived [2] steps
# Total reward [0.6438279151916504]
# step 2064: Survived [1] steps
# Total reward [-0.188704252243042]
# loss = 6.453756
# step 2078: Survived [13] steps
# Total reward [9.830870389938354]
# step 2079: Survived [0] steps
# Total reward [-1.0]
# step 2080: Survived [0] steps
# Total reward [-1.0]
# step 2083: Survived [2] steps
# Total reward [0.432096004486084]
# step 2088: Survived [4] steps
# Total reward [2.115386962890625]
# step 2090: Survived [1] steps
# Total reward [-0.25526857376098633]
# step 2094: Survived [3] steps
# Total reward [1.2856602668762207]
# step 2097: Survived [2] steps
# Total reward [0.5529212951660156]
# step 2102: Survived [4] steps
# Total reward [1.9734129905700684]
# step 2104: Survived [1] steps
# Total reward [-0.19079720973968506]
# step 2108: Survived [3] steps
# Total reward [1.2934995889663696]
# step 2110: Survived [1] steps
# Total reward [-0.1881558895111084]
# step 2113: Survived [2] steps
# Total reward [0.4999206066131592]
# step 2114: Survived [0] steps
# Total reward [-1.0]
# step 2121: Survived [6] steps
# Total reward [3.5042684078216553]
# step 2122: Survived [0] steps
# Total reward [-1.0]
# loss = 2.321447
# step 2129: Survived [6] steps
# Total reward [3.646683096885681]
# step 2130: Survived [0] steps
# Total reward [-1.0]
# step 2133: Survived [2] steps
# Total reward [0.5416290760040283]
# step 2139: Survived [5] steps
# Total reward [2.9191203117370605]
# step 2140: Survived [0] steps
# Total reward [-1.0]
# step 2143: Survived [2] steps
# Total reward [0.6621644496917725]
# step 2146: Survived [2] steps
# Total reward [0.6465775966644287]
# step 2152: Survived [5] steps
# Total reward [2.8610429763793945]
# step 2155: Survived [2] steps
# Total reward [0.5682724714279175]
# step 2156: Survived [0] steps
# Total reward [-1.0]
# step 2161: Survived [4] steps
# Total reward [1.951100468635559]
# step 2165: Survived [3] steps
# Total reward [1.4385699033737183]
# step 2166: Survived [0] steps
# Total reward [-1.0]
# step 2177: Survived [10] steps
# Total reward [6.1674968004226685]
# step 2181: Survived [3] steps
# Total reward [1.2132458686828613]
# loss = 2.5944927
# step 2189: Survived [7] steps
# Total reward [4.522041440010071]
# step 2191: Survived [1] steps
# Total reward [-0.24381232261657715]
# step 2197: Survived [5] steps
# Total reward [3.0028152465820312]
# step 2202: Survived [4] steps
# Total reward [2.1627880334854126]
# step 2205: Survived [2] steps
# Total reward [0.45169973373413086]
# step 2208: Survived [2] steps
# Total reward [0.5564838647842407]
# step 2214: Survived [5] steps
# Total reward [2.8918368816375732]
# step 2218: Survived [3] steps
# Total reward [1.2330864667892456]
# step 2219: Survived [0] steps
# Total reward [-1.0]
# step 2223: Survived [3] steps
# Total reward [1.440334439277649]
# step 2231: Survived [7] steps
# Total reward [4.098577499389648]
# step 2235: Survived [3] steps
# Total reward [1.1075303554534912]
# step 2238: Survived [2] steps
# Total reward [0.6250126361846924]
# loss = 3.16224
# step 2243: Survived [4] steps
# Total reward [1.8116850852966309]
# step 2247: Survived [3] steps
# Total reward [1.2978209257125854]
# step 2256: Survived [8] steps
# Total reward [5.455861926078796]
# step 2259: Survived [2] steps
# Total reward [0.5380598306655884]
# step 2263: Survived [3] steps
# Total reward [1.3644354343414307]
# step 2265: Survived [1] steps
# Total reward [-0.29017019271850586]
# step 2266: Survived [0] steps
# Total reward [-1.0]
# step 2269: Survived [2] steps
# Total reward [0.442071795463562]
# step 2270: Survived [0] steps
# Total reward [-1.0]
# step 2272: Survived [1] steps
# Total reward [-0.21167922019958496]
# step 2278: Survived [5] steps
# Total reward [2.9895769357681274]
# step 2280: Survived [1] steps
# Total reward [-0.214493989944458]
# step 2283: Survived [2] steps
# Total reward [0.34995710849761963]
# step 2284: Survived [0] steps
# Total reward [-1.0]
# step 2289: Survived [4] steps
# Total reward [1.8724256753921509]
# step 2292: Survived [2] steps
# Total reward [0.6272766590118408]
# loss = 3.667841
# step 2296: Survived [3] steps
# Total reward [1.1740003824234009]
# step 2297: Survived [0] steps
# Total reward [-1.0]
# step 2302: Survived [4] steps
# Total reward [2.1604644060134888]
# step 2305: Survived [2] steps
# Total reward [0.20039677619934082]
# step 2309: Survived [3] steps
# Total reward [1.3569972515106201]
# step 2312: Survived [2] steps
# Total reward [0.4619009494781494]
# step 2313: Survived [0] steps
# Total reward [-1.0]
# step 2316: Survived [2] steps
# Total reward [0.5874497890472412]
# step 2321: Survived [4] steps
# Total reward [2.1684634685516357]
# step 2324: Survived [2] steps
# Total reward [0.517040491104126]
# step 2329: Survived [4] steps
# Total reward [2.154364824295044]
# step 2330: Survived [0] steps
# Total reward [-1.0]
# step 2335: Survived [4] steps
# Total reward [2.0312952995300293]
# step 2341: Survived [5] steps
# Total reward [2.6481040716171265]
# step 2344: Survived [2] steps
# Total reward [0.519942045211792]
# loss = 2.95331
# step 2353: Survived [8] steps
# Total reward [5.028199195861816]
# step 2358: Survived [4] steps
# Total reward [1.7014440298080444]
# step 2361: Survived [2] steps
# Total reward [0.5177520513534546]
# step 2366: Survived [4] steps
# Total reward [2.2736687660217285]
# step 2370: Survived [3] steps
# Total reward [1.2713112831115723]
# step 2379: Survived [8] steps
# Total reward [5.170345067977905]
# step 2381: Survived [1] steps
# Total reward [-0.22600245475769043]
# step 2384: Survived [2] steps
# Total reward [0.5602831840515137]
# step 2386: Survived [1] steps
# Total reward [-0.2808818817138672]
# step 2387: Survived [0] steps
# Total reward [-1.0]
# step 2390: Survived [2] steps
# Total reward [0.5411627292633057]
# step 2392: Survived [1] steps
# Total reward [-0.2252490520477295]
# step 2397: Survived [4] steps
# Total reward [2.2022796869277954]
# step 2402: Survived [4] steps
# Total reward [1.8091776371002197]
# step 2404: Survived [1] steps
# Total reward [-0.22448086738586426]
# step 2407: Survived [2] steps
# Total reward [0.49085545539855957]
# loss = 2.090572
# step 2412: Survived [4] steps
# Total reward [2.0571346282958984]
# step 2420: Survived [7] steps
# Total reward [4.16316032409668]
# step 2421: Survived [0] steps
# Total reward [-1.0]
# step 2424: Survived [2] steps
# Total reward [0.35483837127685547]
# step 2428: Survived [3] steps
# Total reward [1.2762973308563232]
# step 2434: Survived [5] steps
# Total reward [2.855870485305786]
# step 2438: Survived [3] steps
# Total reward [1.325813889503479]
# step 2442: Survived [3] steps
# Total reward [1.1616286039352417]
# step 2445: Survived [2] steps
# Total reward [0.49910974502563477]
# step 2449: Survived [3] steps
# Total reward [1.101302146911621]
# step 2454: Survived [4] steps
# Total reward [2.0004968643188477]
# step 2458: Survived [3] steps
# Total reward [1.3023453950881958]
# step 2461: Survived [2] steps
# Total reward [0.4742395877838135]
# step 2463: Survived [1] steps
# Total reward [-0.22642779350280762]
# loss = 0.81743807
# step 2465: Survived [1] steps
# Total reward [-0.23511922359466553]
# step 2471: Survived [5] steps
# Total reward [3.0327247381210327]
# step 2472: Survived [0] steps
# Total reward [-1.0]
# step 2474: Survived [1] steps
# Total reward [-0.25499415397644043]
# step 2478: Survived [3] steps
# Total reward [1.4382007122039795]
# step 2479: Survived [0] steps
# Total reward [-1.0]
# step 2480: Survived [0] steps
# Total reward [-1.0]
# step 2481: Survived [0] steps
# Total reward [-1.0]
# step 2485: Survived [3] steps
# Total reward [1.46755850315094]
# step 2489: Survived [3] steps
# Total reward [1.4729150533676147]
# step 2492: Survived [2] steps
# Total reward [0.5064197778701782]
# step 2495: Survived [2] steps
# Total reward [0.5559813976287842]
# step 2499: Survived [3] steps
# Total reward [1.3710474967956543]
# step 2500: Survived [0] steps
# Total reward [-1.0]
# step 2503: Survived [2] steps
# Total reward [0.5303522348403931]
# step 2508: Survived [4] steps
# Total reward [1.9380571842193604]
# step 2512: Survived [3] steps
# Total reward [1.240659475326538]
# step 2513: Survived [0] steps
# Total reward [-1.0]
# step 2515: Survived [1] steps
# Total reward [-0.23695778846740723]
# loss = 3.4688745
# step 2520: Survived [4] steps
# Total reward [1.9294450283050537]
# step 2523: Survived [2] steps
# Total reward [0.5342264175415039]
# step 2526: Survived [2] steps
# Total reward [0.538794755935669]
# step 2530: Survived [3] steps
# Total reward [1.3113925457000732]
# step 2534: Survived [3] steps
# Total reward [1.0885778665542603]
# step 2538: Survived [3] steps
# Total reward [1.2817920446395874]
# step 2542: Survived [3] steps
# Total reward [1.4890704154968262]
# step 2553: Survived [10] steps
# Total reward [6.526378750801086]
# step 2555: Survived [1] steps
# Total reward [-0.18796753883361816]
# step 2558: Survived [2] steps
# Total reward [0.5067353248596191]
# step 2561: Survived [2] steps
# Total reward [0.4281477928161621]
# step 2566: Survived [4] steps
# Total reward [2.204422116279602]
# step 2572: Survived [5] steps
# Total reward [3.100234627723694]
# step 2573: Survived [0] steps
# Total reward [-1.0]
# step 2575: Survived [1] steps
# Total reward [-0.17403864860534668]
# loss = 4.3841796
# step 2581: Survived [5] steps
# Total reward [2.962118148803711]
# step 2587: Survived [5] steps
# Total reward [2.9461252689361572]
# step 2594: Survived [6] steps
# Total reward [3.839208960533142]
# step 2595: Survived [0] steps
# Total reward [-1.0]
# step 2599: Survived [3] steps
# Total reward [1.3388704061508179]
# step 2602: Survived [2] steps
# Total reward [0.465625524520874]
# step 2604: Survived [1] steps
# Total reward [-0.24724626541137695]
# step 2609: Survived [4] steps
# Total reward [2.1054877042770386]
# step 2611: Survived [1] steps
# Total reward [-0.35210251808166504]
# step 2612: Survived [0] steps
# Total reward [-1.0]
# step 2615: Survived [2] steps
# Total reward [0.5085564851760864]
# step 2618: Survived [2] steps
# Total reward [0.6639577150344849]
# step 2623: Survived [4] steps
# Total reward [1.9092391729354858]
# step 2625: Survived [1] steps
# Total reward [-0.20067882537841797]
# step 2628: Survived [2] steps
# Total reward [0.1063162088394165]
# step 2630: Survived [1] steps
# Total reward [-0.285442590713501]
# step 2631: Survived [0] steps
# Total reward [-1.0]
# loss = 4.572112
# step 2636: Survived [4] steps
# Total reward [2.1081286668777466]
# step 2641: Survived [4] steps
# Total reward [2.1987032890319824]
# step 2644: Survived [2] steps
# Total reward [0.5350027084350586]
# step 2646: Survived [1] steps
# Total reward [-0.3128030300140381]
# step 2650: Survived [3] steps
# Total reward [1.4152487516403198]
# step 2653: Survived [2] steps
# Total reward [0.45865321159362793]
# step 2655: Survived [1] steps
# Total reward [-0.20878028869628906]
# step 2657: Survived [1] steps
# Total reward [-0.22607052326202393]
# step 2661: Survived [3] steps
# Total reward [1.157543420791626]
# step 2668: Survived [6] steps
# Total reward [3.93837571144104]
# step 2670: Survived [1] steps
# Total reward [-0.2120499610900879]
# step 2673: Survived [2] steps
# Total reward [0.559704065322876]
# step 2678: Survived [4] steps
# Total reward [1.8920114040374756]
# step 2680: Survived [1] steps
# Total reward [-0.17644143104553223]
# step 2681: Survived [0] steps
# Total reward [-1.0]
# step 2685: Survived [3] steps
# Total reward [1.4151173830032349]
# loss = 4.830308
# step 2689: Survived [3] steps
# ...
# step 18899: Survived [18] steps
# Total reward [13.226913094520569]
# step 18906: Survived [6] steps
# Total reward [3.941320300102234]
# loss = 0.0015585168
# loss = 0.002008276
# Step [19000] -- Random [0.025274875290302052]
# step 19019: Survived [112] steps
# Total reward [92.08061826229095]
# loss = 0.0015134454
# step 19052: Survived [32] steps
# Total reward [24.441550731658936]
# loss = 0.00081953406
# step 19121: Survived [68] steps
# Total reward [54.93866050243378]
# loss = 0.0019361847
# loss = 0.0017501753
# step 19217: Survived [95] steps
# Total reward [71.06854856014252]
# 130 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch lower than pmin - pmax  [it would be always invalid because, even if the sepoint is pmax, this dispatch would set it to a number bellow pmin, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 130 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch lower than pmin - pmax  [it would be always invalid because, even if the sepoint is pmax, this dispatch would set it to a number bellow pmin, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 130 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch lower than pmin - pmax  [it would be always invalid because, even if the sepoint is pmax, this dispatch would set it to a number bellow pmin, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 130 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch lower than pmin - pmax  [it would be always invalid because, even if the sepoint is pmax, this dispatch would set it to a number bellow pmin, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# 130 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch lower than pmin - pmax  [it would be always invalid because, even if the sepoint is pmax, this dispatch would set it to a number bellow pmin, which is impossible]. Invalid dispatch for generator(s): [1]',)], 'rewards': {}}
# loss = 0.0010877895
# loss = 0.0012762843
# step 19337: Survived [119] steps
# Total reward [83.70942777395248]
# loss = 0.0012982399
# loss = 0.00095036067
# step 19469: Survived [131] steps
# Total reward [103.8239289522171]
# loss = 0.0007169177
# step 19488: Survived [18] steps
# Total reward [13.651066541671753]
# step 19495: Survived [6] steps
# Total reward [3.582463264465332]
# step 19520: Survived [24] steps
# Total reward [18.468466758728027]
# loss = 0.00029356804
# loss = 0.0006009126
# step 19613: Survived [92] steps
# Total reward [77.73851442337036]
# loss = 0.0002669896
# step 19690: Survived [76] steps
# Total reward [63.30518317222595]
# loss = 0.00014868093
# step 19742: Survived [51] steps
# Total reward [40.4158616065979]
# step 19766: Survived [23] steps
# Total reward [16.896281957626343]
# loss = 0.00078675477
# step 19796: Survived [29] steps
# Total reward [21.538093209266663]
# loss = 0.0007200809
# step 19830: Survived [33] steps
# Total reward [24.52056312561035]
# loss = 0.0006210434
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# 118 {'disc_lines': array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False]), 'is_illegal': False, 'is_ambiguous': False, 'is_dispatching_illegal': True, 'is_illegal_reco': False, 'opponent_attack_line': None, 'opponent_attack_sub': None, 'opponent_attack_duration': 0, 'exception': [Grid2OpException AmbiguousAction InvalidRedispatching InvalidRedispatching('You cannot ask for a dispatch higher than pmax - pmin  [it would be always invalid because, even if the sepoint is pmin, this dispatch would set it to a number higher than pmax, which is impossible]. Invalid dispatch for generator(s): [0]',)], 'rewards': {}}
# step 19915: Survived [84] steps
# Total reward [56.62510871887207]
# loss = 0.0008483686
# step 19939: Survived [23] steps
# Total reward [16.809526681900024]
# step 19948: Survived [8] steps
# Total reward [5.142468333244324]
# step 19957: Survived [8] steps
# Total reward [5.034765124320984]
# step 19966: Survived [8] steps
# Total reward [5.068756461143494]
# step 19975: Survived [8] steps
# Total reward [5.146888732910156]
# loss = 0.0002536314
# step 19998: Survived [22] steps
# Total reward [16.76245605945587]
# Step [20000] -- Random [0.01]
# Successfully saved model at: saved_agent_DDDQN_no_opponent_20000/DDDQN.h5
# step 20008: Survived [9] steps
# Total reward [6.402742028236389]
# step 20040: Survived [31] steps
# Total reward [22.76671814918518]
# loss = 0.0004154129
# step 20053: Survived [12] steps
# Total reward [8.434131622314453]
# step 20071: Survived [17] steps
# Total reward [12.376041650772095]
# loss = 0.00055656966
# step 20105: Survived [33] steps
# Total reward [25.31142008304596]
# loss = 0.00073795085
# step 20183: Survived [77] steps
# Total reward [64.24437010288239]
# step 20192: Survived [8] steps
# Total reward [5.137319803237915]
# step 20203: Survived [10] steps
# Total reward [6.941113114356995]
# loss = 0.0014031072
# step 20216: Survived [12] steps
# Total reward [8.651333689689636]
# step 20233: Survived [16] steps
# Total reward [11.747784614562988]
# step 20242: Survived [8] steps
# Total reward [5.214045286178589]
# Successfully saved model at: saved_agent_DDDQN_no_opponent_20000/DDDQN.h5
